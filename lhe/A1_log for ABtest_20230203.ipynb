# %% [markdown]
# ## Data log 에 관하여

# %% [markdown]
# - Final goal : click 율을 높힐 수 있는 방법을 찾자.
#
# - 1차 목적 : log data 파악 (기준 action_type별로)
#
# - 1차 질문 : Conversion Rate를 알 수 있는가? 알 수 없음..
#
#         Funnel 별 이탈률 - **DAU 기준**? **Session **기준?
#         * DAU (Daily Active User) / Session(total visit-방문 할 때 마다 증가하는 수치를 의미한다.)
#
#
#       : 재방문율(retention)은 어떠한가 ? - 동일한 uid를 가지고 있는 사람의 방문수를 분석
#
#       : 분석의 한계점 및 논의/개선 사항에 대하여?
#
# - 2차 목적 : action_type 별로 행동의 패턴을 세분화하여 시간별 패턴을 파악해보려함. >> 핵심그룹 타겟팅
# - 2차 질문 : 상위 10개 지역별 유저의 행동 패턴의 차이?
#          : action_type 에 따른 카테고리별 파악 view 에서 가구수가 많이 찍혔다면, 그 카테고리에 marketing 적인 시도를 할 수 있지 않을까?
#
#
# * 아하-모먼트 : 사용자가 제품을 사용하면서 가치를 발견하는 순간을 말한다.
#  - A-ha 모먼트를 경험한 유저들을 서비스를 계속 사용하게 되고, 이것을 경험하지 못한 유저가 계속 쓰지 않게 되는 현상.
#  - 아하 모먼트의 기준 : X 라는 행동을 가입한지 Y라는 날짜 안에 Z 번 한다.
#
# * 상관관계가 아닌 인과관계를 찾는것이 중요하다. - 인과관계 분석

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import warnings 
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
filename = '/content/drive/MyDrive/data/a1_factory /data/log_csv.csv'
log = pd.read_csv(filename , index_col = 0, parse_dates = ['collect_time'])

# %%
log_cp = log.copy()

# %%
log_cp.set_index('collect_time', inplace = True)

# %%
log_cp = log_cp.sort_index(ascending=True)
log_cp.head()
# Out:
#                                   uid action_type category1 category2  \
# collect_time
# 2022-12-22 00:00:00  PUiJdmOi9ZcADXtx        View        가구     행거·옷장
# 2022-12-22 00:00:01  ch2Z1WDxeWsADNoO        View        가구        거울
# 2022-12-22 00:00:01  Pf2LhGOjGFEADj1W   Highlight        조명      장스탠드
# 2022-12-22 00:00:01  2ugHxGMJssgAAxNY        View     수납·정리       옷걸이
# 2022-12-22 00:00:01               NaN        View        가구        소파
#
#                     category3 geoip_city_name useragent_os  viewrate  viewtime
# collect_time
# 2022-12-22 00:00:00        행거     Jungnang-gu     Mac OS X     100.0     48015
# 2022-12-22 00:00:01      전신거울     Hwaseong-si     Mac OS X     100.0    110654
# 2022-12-22 00:00:01       NaN     Seongnam-si      Windows       0.0         0
# 2022-12-22 00:00:01   바지·치마걸이           Seoul      Android     100.0    222355
# 2022-12-22 00:00:01      일반소파       Seocho-gu      Android       0.0         0

# %%
log_cp['day'] = log_cp.index.day
log_cp['month'] = log_cp.index.month
log_cp
# Out:
#                                   uid action_type category1  category2  \
# collect_time
# 2022-12-22 00:00:00  PUiJdmOi9ZcADXtx        View        가구      행거·옷장
# 2022-12-22 00:00:01  ch2Z1WDxeWsADNoO        View        가구         거울
# 2022-12-22 00:00:01  Pf2LhGOjGFEADj1W   Highlight        조명       장스탠드
# 2022-12-22 00:00:01  2ugHxGMJssgAAxNY        View     수납·정리        옷걸이
# 2022-12-22 00:00:01               NaN        View        가구         소파
# ...                               ...         ...       ...        ...
# 2022-12-30 13:59:59  PWmyWWLCQaIACian        View    가전·디지털         TV
# 2022-12-30 13:59:59  yoiUPmOub5YACv3H        View     수납·정리    서랍장·트롤리
# 2022-12-30 13:59:59  KlKoJGE9yeEACCVI        View        가구     서랍·수납장
# 2022-12-30 13:59:59  ea06vWGN40sACAs+        View        가구  테이블·식탁·책상
# 2022-12-30 13:59:59  dCfI5WAnvUUACpa+        View    가전·디지털         TV
#
#                              category3 geoip_city_name useragent_os  viewrate  \
# collect_time
# 2022-12-22 00:00:00                 행거     Jungnang-gu     Mac OS X     100.0
# 2022-12-22 00:00:01               전신거울     Hwaseong-si     Mac OS X     100.0
# 2022-12-22 00:00:01                NaN     Seongnam-si      Windows       0.0
# 2022-12-22 00:00:01            바지·치마걸이           Seoul      Android     100.0
# 2022-12-22 00:00:01               일반소파       Seocho-gu      Android       0.0
# ...                                ...             ...          ...       ...
# 2022-12-30 13:59:59       ~109cm(~43")         Daejeon      Windows     100.0
# 2022-12-30 13:59:59          트롤리·이동식선반           Seoul          iOS     100.0
# 2022-12-30 13:59:59                 협탁       Gangneung      Windows     100.0
# 2022-12-30 13:59:59             사이드테이블        Gimpo-si      Windows     100.0
# 2022-12-30 13:59:59  164~188cm(65~74")           Seoul      Windows     100.0
#
#                      viewtime  day  month
# collect_time
# 2022-12-22 00:00:00     48015   22     12
# 2022-12-22 00:00:01    110654   22     12
# 2022-12-22 00:00:01         0   22     12
# 2022-12-22 00:00:01    222355   22     12
# 2022-12-22 00:00:01         0   22     12
# ...                       ...  ...    ...
# 2022-12-30 13:59:59       414   30     12
# 2022-12-30 13:59:59     24722   30     12
# 2022-12-30 13:59:59      3007   30     12
# 2022-12-30 13:59:59     81011   30     12
# 2022-12-30 13:59:59     44005   30     12
#
# [5659541 rows x 11 columns]

# %%
# 일자별로 uid 중복행을 - 재방문으로 보고 비율 표시 :  Retention을 어떻게

# %%
log_cp.groupby(['uid']).day

# %%
# data information 
def df_info(df):
  print('data set information: \n')
  print(df.info())

  print('data set describe check : \n')
  print(df.describe())

df_info(log)
# Out:
# data set information:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5659541 entries, 0 to 5659540
# Data columns (total 10 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   uid              object
#  1   action_type      object
#  2   category1        object
#  3   category2        object
#  4   category3        object
#  5   collect_time     datetime64[ns]
#  6   geoip_city_name  object
#  7   useragent_os     object
#  8   viewrate         float64
#  9   viewtime         int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(7)
# memory usage: 475.0+ MB
# None
# data set describe check :
#
#            viewrate      viewtime
# count  5.657112e+06  5.659541e+06
# mean   7.677686e+01  5.126022e+04
# std    4.221447e+01  5.810345e+05
# min    0.000000e+00  0.000000e+00
# 25%    1.000000e+02  8.940000e+02
# 50%    1.000000e+02  1.010400e+04
# 75%    1.000000e+02  4.800500e+04
# max    1.000000e+02  8.636989e+07

# %%
log.isnull().sum()
# Out:
# uid                186313
# action_type             0
# category1               0
# category2               0
# category3          780006
# collect_time            0
# geoip_city_name    417032
# useragent_os            0
# viewrate             2429
# viewtime                0
# dtype: int64

# %%
log[log.category3.isnull()] #null값의 형태 확인
# Out:
#                       uid action_type category1  category2 category3  \
# 6        Adwku2KoPCwAANbw        View       노하우       꾸미기팁       NaN
# 21       fAWTRWOtPKAABl9P        View        가구     서랍·수납장       NaN
# 54       fYx4OGJwcR4AB+zb        View        조명       단스탠드       NaN
# 61       avXJTWNh0KoAATnH        View       노하우       꾸미기팁       NaN
# 66       0nWGIGNbMn4ACm6Q        View       노하우       지식백과       NaN
# ...                   ...         ...       ...        ...       ...
# 5659495  2icuqmNMnKMAATWT        View     수납·정리   빨래바구니·햄퍼       NaN
# 5659519  dihYQ2Jp53kABkx/        View    가전·디지털       음향가전       NaN
# 5659524  Ae06eGOr4WcACDEv        View      주방용품  보관·용기·도시락       NaN
# 5659526  dCFkG2J3qToAAf3A        View       패브릭  O!STYLING       NaN
# 5659535  0//H1mOs/wgABiw0        View     수납·정리         행거       NaN
#
#                collect_time geoip_city_name useragent_os  viewrate  viewtime
# 6       2022-12-29 09:13:14       Gwanak-gu      Windows     100.0     37161
# 21      2022-12-29 16:09:37     Seongbuk-gu      Windows     100.0      7036
# 54      2022-12-29 09:32:21     Seongnam-si      Windows     100.0      2377
# 61      2022-12-29 15:56:42            Paju      Windows     100.0    134250
# 66      2022-12-29 14:51:55          Jeonju      Windows     100.0    141057
# ...                     ...             ...          ...       ...       ...
# 5659495 2022-12-28 14:26:18           Seoul      Windows     100.0     43181
# 5659519 2022-12-28 12:23:51         Gwangju      Windows     100.0     36011
# 5659524 2022-12-28 17:04:42         Gwangju          iOS     100.0    135321
# 5659526 2022-12-29 18:51:06           Seoul          iOS       0.0         0
# 5659535 2022-12-29 13:14:04           Seoul      Windows     100.0      2006
#
# [780006 rows x 10 columns]

# %%
# data 결측값 처리 
log_null_ts = log.copy()
drop_city = log_null_ts[log_null_ts['geoip_city_name'] != 'Seoul']
drop_city = drop_city[drop_city['geoip_city_name'] != 'Gyeonggi-do']


drop_city.isnull().sum().sort_values(ascending=False)
# Out:
# category3          643126
# geoip_city_name    417032
# uid                132162
# viewrate             1722
# action_type             0
# category1               0
# category2               0
# collect_time            0
# useragent_os            0
# viewtime                0
# dtype: int64

# %%
log_drop_null = drop_city 
log_drop_null['geoip_city_name'].fillna('un_city_name', inplace = True)
log_drop_null['category3'].fillna('un_category', inplace = True)
log_drop_null['uid'].fillna('unname',inplace= True)
log_drop_null.dropna(axis= 0, inplace =True)
print(log_drop_null.isnull().sum().sort_values(ascending=False))
# Out:
# uid                0
# action_type        0
# category1          0
# category2          0
# category3          0
# collect_time       0
# geoip_city_name    0
# useragent_os       0
# viewrate           0
# viewtime           0
# dtype: int64

# %%
log_drop_null
# Out:
#                       uid action_type category1  category2 category3  \
# 0        avpKyWMn/xEADNlb        View      주방용품     그릇·홈세트   식판·나눔접시
# 1        0+5vEmGkOuAAB5j2      Basket       패브릭         매트  주방·다용도매트
# 3        dC9Fl2Ly9lcADrTn   Highlight     데코·식물     플라워·식물     화병·화분
# 4        09gKcGLg0I8ACyQy        View        가구     진열장·책장        책장
# 5        091fXGIDYFEABcpA      Basket     수납·정리  화장대·테이블정리  티슈커버·케이스
# ...                   ...         ...       ...        ...       ...
# 5659533  3yfy5mOZpbYAAMpw        View    가전·디지털       주방가전  오븐·전자레인지
# 5659534  qE73wWOr1C8ABhBw        View      캠핑용품     캠핑생활용품  기타캠핑생활용품
# 5659537  PVMstmNg4I4ADq9R      Basket        가구     진열장·책장        책장
# 5659538  diRXdmN49dUABrVo        View        가구  테이블·식탁·책상        식탁
# 5659540  bgy5ZGOszc4ADrmd        View        가구     화장대·콘솔     일반화장대
#
#                collect_time geoip_city_name useragent_os  viewrate  viewtime
# 0       2022-12-29 17:29:02     Seongnam-si      Windows     100.0     80033
# 1       2022-12-29 12:56:38       Yongin-si      Windows       0.0         0
# 3       2022-12-29 17:54:30  Gwangmyeong-si      Windows       0.0         0
# 4       2022-12-29 18:45:05       Jongno-gu     Mac OS X     100.0      1238
# 5       2022-12-29 17:53:11         Incheon      Windows       0.0         0
# ...                     ...             ...          ...       ...       ...
# 5659533 2022-12-29 12:45:14      Gangnam-gu      Android     100.0      6054
# 5659534 2022-12-28 15:40:29       Songpa-gu      Windows     100.0     10006
# 5659537 2022-12-28 14:30:09           Jinju      Windows       0.0         0
# 5659538 2022-12-29 12:45:13           Gunpo      Android     100.0     47217
# 5659540 2022-12-29 08:14:39           Iksan          iOS       0.0         0
#
# [4671060 rows x 10 columns]

# %%
# uid 의 중복을 없앰
log_new = log_drop_null.drop_duplicates(['uid'])

# %%
log_new
# Out:
#                       uid action_type category1  category2    category3  \
# 0        avpKyWMn/xEADNlb        View      주방용품     그릇·홈세트      식판·나눔접시
# 1        0+5vEmGkOuAAB5j2      Basket       패브릭         매트     주방·다용도매트
# 3        dC9Fl2Ly9lcADrTn   Highlight     데코·식물     플라워·식물        화병·화분
# 4        09gKcGLg0I8ACyQy        View        가구     진열장·책장           책장
# 5        091fXGIDYFEABcpA      Basket     수납·정리  화장대·테이블정리     티슈커버·케이스
# ...                   ...         ...       ...        ...          ...
# 5659447  DiETNWGKOwMADDsp        View    가전·디지털      태블릿PC        태블릿PC
# 5659459  amWDVmOr0ycAB/2J        View        가구  테이블·식탁·책상       사이드테이블
# 5659462  DiaRu2I60NgACwX7        View       노하우      건축&주택  un_category
# 5659472  0/usD2Os6BcACzMc        View       패브릭     매트리스커버  un_category
# 5659491  dusqTmOtPa8AB46D        View       패브릭     이불·이불솜           이불
#
#                collect_time geoip_city_name useragent_os  viewrate  viewtime
# 0       2022-12-29 17:29:02     Seongnam-si      Windows     100.0     80033
# 1       2022-12-29 12:56:38       Yongin-si      Windows       0.0         0
# 3       2022-12-29 17:54:30  Gwangmyeong-si      Windows       0.0         0
# 4       2022-12-29 18:45:05       Jongno-gu     Mac OS X     100.0      1238
# 5       2022-12-29 17:53:11         Incheon      Windows       0.0         0
# ...                     ...             ...          ...       ...       ...
# 5659447 2022-12-28 17:18:27       Yongin-si      Windows     100.0      7572
# 5659459 2022-12-28 22:12:53      Gangbuk-gu          iOS     100.0    287291
# 5659462 2022-12-29 10:54:12     Seongnam-si      Windows     100.0    228039
# 5659472 2022-12-29 10:07:13        Changwon      Windows     100.0     58595
# 5659491 2022-12-29 16:11:49           Busan          iOS     100.0      9633
#
# [647910 rows x 10 columns]

# %%
non_basket = log_new[log_new['action_type'] != 'Basket']
non_basket
# Out:
#                       uid action_type category1  category2    category3  \
# 0        avpKyWMn/xEADNlb        View      주방용품     그릇·홈세트      식판·나눔접시
# 3        dC9Fl2Ly9lcADrTn   Highlight     데코·식물     플라워·식물        화병·화분
# 4        09gKcGLg0I8ACyQy        View        가구     진열장·책장           책장
# 6        Adwku2KoPCwAANbw        View       노하우       꾸미기팁  un_category
# 7        tOQhrWGfQcAACo9B        View        가구  테이블·식탁·책상           책상
# ...                   ...         ...       ...        ...          ...
# 5659447  DiETNWGKOwMADDsp        View    가전·디지털      태블릿PC        태블릿PC
# 5659459  amWDVmOr0ycAB/2J        View        가구  테이블·식탁·책상       사이드테이블
# 5659462  DiaRu2I60NgACwX7        View       노하우      건축&주택  un_category
# 5659472  0/usD2Os6BcACzMc        View       패브릭     매트리스커버  un_category
# 5659491  dusqTmOtPa8AB46D        View       패브릭     이불·이불솜           이불
#
#                collect_time geoip_city_name useragent_os  viewrate  viewtime
# 0       2022-12-29 17:29:02     Seongnam-si      Windows     100.0     80033
# 3       2022-12-29 17:54:30  Gwangmyeong-si      Windows       0.0         0
# 4       2022-12-29 18:45:05       Jongno-gu     Mac OS X     100.0      1238
# 6       2022-12-29 09:13:14       Gwanak-gu      Windows     100.0     37161
# 7       2022-12-29 15:32:12      Gangnam-gu      Windows     100.0      8483
# ...                     ...             ...          ...       ...       ...
# 5659447 2022-12-28 17:18:27       Yongin-si      Windows     100.0      7572
# 5659459 2022-12-28 22:12:53      Gangbuk-gu          iOS     100.0    287291
# 5659462 2022-12-29 10:54:12     Seongnam-si      Windows     100.0    228039
# 5659472 2022-12-29 10:07:13        Changwon      Windows     100.0     58595
# 5659491 2022-12-29 16:11:49           Busan          iOS     100.0      9633
#
# [642007 rows x 10 columns]

# %%
geo_rank = non_basket.loc[:,'geoip_city_name'].value_counts()[1:10]
geo_rank
# 많이 이용하는 지역 상위 10개
# Out:
# Busan          30033
# Incheon        26633
# Daegu          23823
# Seongnam-si    18937
# Daejeon        18709
# Gwangju        17863
# Suwon          17087
# Yongin-si      16550
# Gangnam-gu     14908
# Name: geoip_city_name, dtype: int64

# %%
geo_rank.index
# Out:
# Index(['Busan', 'Incheon', 'Daegu', 'Seongnam-si', 'Daejeon', 'Gwangju',
#        'Suwon', 'Yongin-si', 'Gangnam-gu'],
#       dtype='object')

# %%
# 지역 상위 10개 내에서 action_type별 행동 분석 why? 
# 지역별 category 어떤 category의 선호도가 높은지 ? 전체적인 흐름과 비슷한 선호도를 보이고 있는가? 
filter = (non_basket['geoip_city_name'] == 'Busan') & (non_basket['action_type'] =='View') 
busan_view = non_basket[filter]
busan_view
# Out:
#                       uid action_type category1  category2    category3  \
# 27       eZBeZ2GDmxMAA7AM        View        가구     서랍·수납장          수납장
# 58       G3VZr2L7PcUACeaU        View       패브릭       홈패브릭       담요·블랭킷
# 182      0rTXAmOtE08ADdVm        View        가구     서랍·수납장        주방수납장
# 191      ei+4MWL+soMADPvJ        View        가구  테이블·식탁·책상  un_category
# 194      3FSihmNzOpYABmd/        View    먼데이하우스         가구    테이블·식탁·책상
# ...                   ...         ...       ...        ...          ...
# 5656853  d0Ge1WOtMlAADBp+        View        가구  테이블·식탁·책상           식탁
# 5657141  dW8Ou2Kaok0ADtRJ        View       노하우         청소  un_category
# 5657757  3yfSmWNEAQ4ADes/        View        가구         침대      침대+매트리스
# 5658369  3Y2sYGOrHFMADSmp        View      주방용품     칼·커팅기구          칼세트
# 5659491  dusqTmOtPa8AB46D        View       패브릭     이불·이불솜           이불
#
#                collect_time geoip_city_name useragent_os  viewrate  viewtime
# 27      2022-12-29 11:39:18           Busan      Windows     100.0     16164
# 58      2022-12-29 10:09:17           Busan      Android     100.0      3400
# 182     2022-12-29 13:22:18           Busan      Windows     100.0     11012
# 191     2022-12-24 23:16:52           Busan      Android     100.0     14031
# 194     2022-12-26 15:53:22           Busan      Windows     100.0      7036
# ...                     ...             ...          ...       ...       ...
# 5656853 2022-12-29 15:26:12           Busan      Windows     100.0     12656
# 5657141 2022-12-29 14:18:48           Busan      Android     100.0     42876
# 5657757 2022-12-28 08:12:16           Busan      Android       0.0         0
# 5658369 2022-12-28 14:43:39           Busan          iOS     100.0     43037
# 5659491 2022-12-29 16:11:49           Busan          iOS     100.0      9633
#
# [29006 rows x 10 columns]

# %%
busan_view['category1'].value_counts()[:10]
# Out:
# 가구        8445
# 가전·디지털    4030
# 노하우       2649
# 패브릭       2644
# 주방용품      2644
# 데코·식물     2331
# 생활용품      1363
# 수납·정리     1043
# 공구·DIY     793
# 조명         769
# Name: category1, dtype: int64

# %%
busan_view['category1'].value_counts()[:10].plot.bar()

# %%
# highlight 
filter = (non_basket['geoip_city_name'] == 'Busan') & (non_basket['action_type'] =='Highlight') 
busan_highlight = non_basket[filter]
busan_highlight
# Out:
#                       uid action_type category1  category2    category3  \
# 616      avD3ymNoPuoADcCj   Highlight      생활용품       세탁용품        빨래건조대
# 955      Oxg1Q2Ho6v0ADE5v   Highlight      주방용품    컵·잔·텀블러          맥주잔
# 976      duspm2OnOfoAAdRV   Highlight     수납·정리  화장대·테이블정리     소품정리·거치대
# 1169     ebHacGJiDykADpiC   Highlight    가전·디지털       계절가전          가습기
# 1680     avudWWNGMNkAA1oL   Highlight    가전·디지털       계절가전        공기청정기
# ...                   ...         ...       ...        ...          ...
# 4965035  dCzDimMTNIgADmZI   Highlight       노하우         청소  un_category
# 5107436  didx8WOr1/UACy6P   Highlight       노하우         수납  un_category
# 5416668  PU9OpWOm7bUAARgp   Highlight       패브릭     이불·이불솜           이불
# 5494331  07binWOr7TYAAbG3   Highlight      주방용품    컵·잔·텀블러   와인·양주·칵테일잔
# 5600400  Diq3qmFi0lkADaNp   Highlight       생필품       양치용품           치약
#
#                collect_time geoip_city_name useragent_os  viewrate  viewtime
# 616     2022-12-29 13:38:23           Busan      Windows       0.0         0
# 955     2022-12-22 10:50:48           Busan      Windows       0.0         0
# 976     2022-12-25 02:42:37           Busan          iOS       0.0         0
# 1169    2022-12-24 13:47:23           Busan      Android       0.0         0
# 1680    2022-12-26 12:23:43           Busan      Windows       0.0         0
# ...                     ...             ...          ...       ...       ...
# 4965035 2022-12-23 21:33:43           Busan      Windows       0.0         0
# 5107436 2022-12-28 14:46:08           Busan          iOS       0.0         0
# 5416668 2022-12-24 21:21:23           Busan      Windows       0.0         0
# 5494331 2022-12-28 16:16:42           Busan          iOS       0.0         0
# 5600400 2022-12-29 19:07:28           Busan      Android       0.0         0
#
# [757 rows x 10 columns]

# %%
busan_highlight['category1'].value_counts()[:10].plot.bar()

# %%
# action_type별 viewtime의 평균 

list = non_basket['action_type'].value_counts()
act_lst = list.index.to_list()
print(act_lst)
# for act_type in act_lst :
#   view_df = non_basket[non_basket['action_type'] == str(act_lst)]

#   print(view_df['viewtime'].mean())
# Out:
# ['View', 'Highlight', 'SINF', 'Copy']

# %%
view_df = non_basket[non_basket['action_type'] == 'View']
view_df['viewtime'].mean()
# Out:
# 72942.07208413526

# %% [markdown]
# # DAU
#  Daily Active User 일일 활성 사용자 수

# %%
type(log_drop_null['collect_time'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
log_drop_null.sort_values(by='collect_time',inplace=True)

# %%
log_drop_null
# Out:
#                       uid action_type category1  category2     category3  \
# 479048   PUiJdmOi9ZcADXtx        View        가구      행거·옷장            행거
# 3893008  Pf2LhGOjGFEADj1W   Highlight        조명       장스탠드   un_category
# 185259             unname        View        가구         소파          일반소파
# 132990   ch2Z1WDxeWsADNoO        View        가구         거울          전신거울
# 4892838  Ok/iZGNvpQIADwDS   Highlight        가구         소파          일반소파
# ...                   ...         ...       ...        ...           ...
# 5574023  07idymOQWBQABDlw        Copy       패브릭     커튼·부자재          암막커튼
# 3592283  fYx4OGN0PJUACMDT        View       패브릭         매트        현관·발매트
# 5561628  diIj92OSuiwACGvT        View      주방용품    주방수납·정리     수세미걸이·세제통
# 5611799  avXigmJ8inIAAe8q        View     데코·식물  데스크·디자인문구        데스크테리어
# 5609974  PWmyWWLCQaIACian        View    가전·디지털         TV  ~109cm(~43")
#
#                collect_time geoip_city_name useragent_os  viewrate  viewtime
# 479048  2022-12-22 00:00:00     Jungnang-gu     Mac OS X     100.0     48015
# 3893008 2022-12-22 00:00:01     Seongnam-si      Windows       0.0         0
# 185259  2022-12-22 00:00:01       Seocho-gu      Android       0.0         0
# 132990  2022-12-22 00:00:01     Hwaseong-si     Mac OS X     100.0    110654
# 4892838 2022-12-22 00:00:01          Sejong      Windows       0.0         0
# ...                     ...             ...          ...       ...       ...
# 5574023 2022-12-30 13:59:59           Busan      Windows       0.0         0
# 3592283 2022-12-30 13:59:59     Seongnam-si      Windows       0.0         0
# 5561628 2022-12-30 13:59:59         Cheonan      Windows     100.0     17172
# 5611799 2022-12-30 13:59:59       Jongno-gu      Windows     100.0     48038
# 5609974 2022-12-30 13:59:59         Daejeon      Windows     100.0       414
#
# [4671060 rows x 10 columns]

# %%
min_grouped = log_drop_null.groupby(['uid'])['collect_time'].min()

# %%
max_grouped = log_drop_null.groupby(['uid'])['collect_time'].max()

# %%
max_time_df = pd.DataFrame(max_grouped)
max_time_df.columns = ['latest']
max_time_df
# Out:
#                               latest
# uid
# 0++3ZGK1UAwAADb+ 2022-12-28 16:12:56
# 0+0E1GJwuzsACQ83 2022-12-28 20:01:45
# 0+0E1GOjv/8ABjEM 2022-12-22 11:28:36
# 0+0E1GOlousACRFf 2022-12-23 21:48:30
# 0+0E1GOo9foAB0Rq 2022-12-26 10:50:13
# ...                              ...
# ztsr/mOubbUAA5Ln 2022-12-30 13:51:16
# ztssBGDawzIADCeb 2022-12-26 08:54:34
# zwYvtWOl6NgADWlA 2022-12-24 02:45:10
# zyaeLmOs57EACT8n 2022-12-29 10:05:15
# zyak/GLq3i0ACWBJ 2022-12-30 11:02:31
#
# [647910 rows x 1 columns]

# %%
min_time_df = pd.DataFrame(min_grouped)
min_time_df.columns = ['start']
min_time_df
# Out:
#                                start
# uid
# 0++3ZGK1UAwAADb+ 2022-12-28 15:20:39
# 0+0E1GJwuzsACQ83 2022-12-28 19:53:21
# 0+0E1GOjv/8ABjEM 2022-12-22 11:28:36
# 0+0E1GOlousACRFf 2022-12-23 21:48:30
# 0+0E1GOo9foAB0Rq 2022-12-26 10:18:15
# ...                              ...
# ztsr/mOubbUAA5Ln 2022-12-30 13:49:23
# ztssBGDawzIADCeb 2022-12-26 08:54:34
# zwYvtWOl6NgADWlA 2022-12-24 02:45:10
# zyaeLmOs57EACT8n 2022-12-29 10:05:15
# zyak/GLq3i0ACWBJ 2022-12-30 10:56:40
#
# [647910 rows x 1 columns]

# %%
new_log = pd.concat([max_time_df, min_time_df], axis =1)
new_log
# Out:
#                               latest               start
# uid
# 0++3ZGK1UAwAADb+ 2022-12-28 16:12:56 2022-12-28 15:20:39
# 0+0E1GJwuzsACQ83 2022-12-28 20:01:45 2022-12-28 19:53:21
# 0+0E1GOjv/8ABjEM 2022-12-22 11:28:36 2022-12-22 11:28:36
# 0+0E1GOlousACRFf 2022-12-23 21:48:30 2022-12-23 21:48:30
# 0+0E1GOo9foAB0Rq 2022-12-26 10:50:13 2022-12-26 10:18:15
# ...                              ...                 ...
# ztsr/mOubbUAA5Ln 2022-12-30 13:51:16 2022-12-30 13:49:23
# ztssBGDawzIADCeb 2022-12-26 08:54:34 2022-12-26 08:54:34
# zwYvtWOl6NgADWlA 2022-12-24 02:45:10 2022-12-24 02:45:10
# zyaeLmOs57EACT8n 2022-12-29 10:05:15 2022-12-29 10:05:15
# zyak/GLq3i0ACWBJ 2022-12-30 11:02:31 2022-12-30 10:56:40
#
# [647910 rows x 2 columns]

# %%
new_log['session_time'] = new_log['latest'] - new_log['start']
new_log
# Out:
#                               latest               start    session_time
# uid
# 0++3ZGK1UAwAADb+ 2022-12-28 16:12:56 2022-12-28 15:20:39 0 days 00:52:17
# 0+0E1GJwuzsACQ83 2022-12-28 20:01:45 2022-12-28 19:53:21 0 days 00:08:24
# 0+0E1GOjv/8ABjEM 2022-12-22 11:28:36 2022-12-22 11:28:36 0 days 00:00:00
# 0+0E1GOlousACRFf 2022-12-23 21:48:30 2022-12-23 21:48:30 0 days 00:00:00
# 0+0E1GOo9foAB0Rq 2022-12-26 10:50:13 2022-12-26 10:18:15 0 days 00:31:58
# ...                              ...                 ...             ...
# ztsr/mOubbUAA5Ln 2022-12-30 13:51:16 2022-12-30 13:49:23 0 days 00:01:53
# ztssBGDawzIADCeb 2022-12-26 08:54:34 2022-12-26 08:54:34 0 days 00:00:00
# zwYvtWOl6NgADWlA 2022-12-24 02:45:10 2022-12-24 02:45:10 0 days 00:00:00
# zyaeLmOs57EACT8n 2022-12-29 10:05:15 2022-12-29 10:05:15 0 days 00:00:00
# zyak/GLq3i0ACWBJ 2022-12-30 11:02:31 2022-12-30 10:56:40 0 days 00:05:51
#
# [647910 rows x 3 columns]

# %% [markdown]
# #Funnel analysis

# %% [markdown]
# reference : https://bigsong.tistory.com/38

# %%
# 다시 한번 불러오기 (basket까지 포함)

# %%
# filename = '/content/drive/MyDrive/data/a1_factory /data/log_csv.csv'
# log = pd.read_csv(filename , index_col = 0, parse_dates = ['collect_time'])

# %%
log_df = log_drop_null[['collect_time', 'uid', 'action_type']].copy()

# %%
log_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4671060 entries, 479048 to 5609974
# Data columns (total 3 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   collect_time  datetime64[ns]
#  1   uid           object
#  2   action_type   object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 142.5+ MB

# %%
type(log_df['collect_time'][0])
#type이 데이트타임인것을 확인.
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
log_df.isnull().sum()
# Out:
# collect_time    0
# uid             0
# action_type     0
# dtype: int64

# %%
log_df.sort_values(by='collect_time',inplace=True)

# %%
log_df
# Out:
#                collect_time               uid action_type
# 479048  2022-12-22 00:00:00  PUiJdmOi9ZcADXtx        View
# 3893008 2022-12-22 00:00:01  Pf2LhGOjGFEADj1W   Highlight
# 185259  2022-12-22 00:00:01            unname        View
# 132990  2022-12-22 00:00:01  ch2Z1WDxeWsADNoO        View
# 4892838 2022-12-22 00:00:01  Ok/iZGNvpQIADwDS   Highlight
# ...                     ...               ...         ...
# 5618180 2022-12-30 13:59:59  PUqeQWOf5qgAAzTM        View
# 4386418 2022-12-30 13:59:59  fbn/GGMdU0MAB0LH        View
# 5621058 2022-12-30 13:59:59  KlKoJGE9yeEACCVI        View
# 5613275 2022-12-30 13:59:59  y/u822NeqBgAAKR2        View
# 5609974 2022-12-30 13:59:59  PWmyWWLCQaIACian        View
#
# [4671060 rows x 3 columns]

# %%
grouped = log_df.groupby(['uid','action_type'])['collect_time'].min() # 시간에 대해 최초접속을 기준으로 하기 위해 min으로 정렬
grouped
# Out:
# uid               action_type
# 0++3ZGK1UAwAADb+  View          2022-12-28 15:20:39
# 0+0E1GJwuzsACQ83  Highlight     2022-12-28 20:01:45
#                   View          2022-12-28 19:53:21
# 0+0E1GOjv/8ABjEM  View          2022-12-22 11:28:36
# 0+0E1GOlousACRFf  View          2022-12-23 21:48:30
#                                         ...
# ztsr/mOubbUAA5Ln  View          2022-12-30 13:49:23
# ztssBGDawzIADCeb  View          2022-12-26 08:54:34
# zwYvtWOl6NgADWlA  View          2022-12-24 02:45:10
# zyaeLmOs57EACT8n  View          2022-12-29 10:05:15
# zyak/GLq3i0ACWBJ  View          2022-12-30 10:56:40
# Name: collect_time, Length: 767530, dtype: datetime64[ns]

# %%
funnel_steps = pd.DataFrame({'steps':[1,2,3]}, index = ['View','Highlight','Basket']) # 여기서 걸리는점은 행동의 순서가 확실치 않다는것이다. 
funnel_steps
# funnel step 을 위한 별도의 데이터 프레임을 생성 (step)
# view -> highlight -> basket
# Out:
#            steps
# View           1
# Highlight      2
# Basket         3

# %%
grouped = pd.DataFrame(grouped).merge(funnel_steps , left_on = 'action_type', right_index = True)
grouped
# Out:
#                                     collect_time  steps
# uid              action_type
# 0++3ZGK1UAwAADb+ View        2022-12-28 15:20:39      1
# 0+0E1GJwuzsACQ83 View        2022-12-28 19:53:21      1
# 0+0E1GOjv/8ABjEM View        2022-12-22 11:28:36      1
# 0+0E1GOlousACRFf View        2022-12-23 21:48:30      1
# 0+0E1GOo9foAB0Rq View        2022-12-26 10:19:42      1
# ...                                          ...    ...
# ypa9UWN/eRgAAHeT Basket      2022-12-26 15:53:21      3
# ypa9WWOo8NwABNiQ Basket      2022-12-26 10:02:31      3
# yqv4AmLOa6cADFL2 Basket      2022-12-23 09:30:54      3
# ytEf/GOauqwABkGu Basket      2022-12-26 22:34:54      3
# z/RHUGONyzUAAJRY Basket      2022-12-23 11:53:06      3
#
# [738181 rows x 2 columns]

# %%
funnel = grouped.reset_index().pivot(index='uid', columns = 'steps', values = 'collect_time')
funnel.columns = funnel_steps.index
funnel
# Out:
#                                 View           Highlight              Basket
# uid
# 0++3ZGK1UAwAADb+ 2022-12-28 15:20:39                 NaT                 NaT
# 0+0E1GJwuzsACQ83 2022-12-28 19:53:21 2022-12-28 20:01:45                 NaT
# 0+0E1GOjv/8ABjEM 2022-12-22 11:28:36                 NaT                 NaT
# 0+0E1GOlousACRFf 2022-12-23 21:48:30                 NaT                 NaT
# 0+0E1GOo9foAB0Rq 2022-12-26 10:19:42 2022-12-26 10:18:15 2022-12-26 10:49:47
# ...                              ...                 ...                 ...
# ztsr/mOubbUAA5Ln 2022-12-30 13:49:23                 NaT                 NaT
# ztssBGDawzIADCeb 2022-12-26 08:54:34                 NaT                 NaT
# zwYvtWOl6NgADWlA 2022-12-24 02:45:10                 NaT                 NaT
# zyaeLmOs57EACT8n 2022-12-29 10:05:15                 NaT                 NaT
# zyak/GLq3i0ACWBJ 2022-12-30 10:56:40                 NaT                 NaT
#
# [647834 rows x 3 columns]

# %%
step_values = [funnel[column].notnull().sum() for column in funnel.columns]
step_values
#`datafram.groupby('column')['column'].nunique()` #this is true way
#view에서 highlight까지는 많은 수치로 줄지만, highlight 에서 basket 까지는 이어지는 경우가 많은 것으로 보여진다.
# Out:
# [646676, 57043, 34462]

# %%
import plotly.express as px
data = dict(
    number = step_values,
    stage = ['View','Highlight','Basket'])
fig = px.funnel(data, x = 'number', y='stage')
fig.show()

# basket / non-basket 그룹 군으로 나누어
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3202163a-752e-4a6b-8aae-d6bef9510270" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3202163a-752e-4a6b-8aae-d6bef9510270")) {                    Plotly.newPlot(                        "3202163a-752e-4a6b-8aae-d6bef9510270",                        [{"hovertemplate":"number=%{x}<br>stage=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","orientation":"h","showlegend":false,"x":[646676,57043,34462],"xaxis":"x","y":["View","Highlight","Basket"],"yaxis":"y","type":"funnel"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"s ...

# %%
# funnel 구간별 소요 시간

# %%
funnel
# Out:
#                                 View           Highlight              Basket
# uid
# 0++3ZGK1UAwAADb+ 2022-12-28 15:20:39                 NaT                 NaT
# 0+0E1GJwuzsACQ83 2022-12-28 19:53:21 2022-12-28 20:01:45                 NaT
# 0+0E1GOjv/8ABjEM 2022-12-22 11:28:36                 NaT                 NaT
# 0+0E1GOlousACRFf 2022-12-23 21:48:30                 NaT                 NaT
# 0+0E1GOo9foAB0Rq 2022-12-26 10:19:42 2022-12-26 10:18:15 2022-12-26 10:49:47
# ...                              ...                 ...                 ...
# ztsr/mOubbUAA5Ln 2022-12-30 13:49:23                 NaT                 NaT
# ztssBGDawzIADCeb 2022-12-26 08:54:34                 NaT                 NaT
# zwYvtWOl6NgADWlA 2022-12-24 02:45:10                 NaT                 NaT
# zyaeLmOs57EACT8n 2022-12-29 10:05:15                 NaT                 NaT
# zyak/GLq3i0ACWBJ 2022-12-30 10:56:40                 NaT                 NaT
#
# [647834 rows x 3 columns]

# %%
# 의미해석

# %%
np.mean(abs(funnel['View']- funnel['Highlight'])) # 뒤에 행동을 하던지 순서 상관없이 많은 시간 소요가 되지 않을테니 절댓값을 취하여 평균값을 계산
# Out:
# Timedelta('0 days 13:44:23.817878609')

# %%
np.mean(abs(funnel['Highlight'] - funnel['Basket']))
# Out:
# Timedelta('0 days 15:58:28.869626639')

# %%
np.mean(funnel['Highlight'] - funnel['Basket'])
# Out:
# Timedelta('0 days 00:19:38.721224352')

# %%
np.mean(abs(funnel['View'] - funnel['Basket']))
# Out:
# Timedelta('0 days 13:57:14.518529325')

# %%
# 따로따로 건드려서 소요시간 측정해보자. (우선 함수만드는 연습이 급선무..)

# %%
# filter = (log_dff.category1 == '가구') | (log_dff.category1 == '가전·디지털') | (log_dff.category1 == '노하우') | (log_dff.category1 == '패브릭') | (log_dff.category1 == '주방용품') | (log_dff.category1 == '데코·식물') | (log_dff.category1 == '생활용품') | (log_dff.category1 == '수납·정리') | (log_dff.category1 == '가전·디지털가전·디지털')

# %%
cat_rank = log_dff.groupby(['uid', 'action_type']).category1.sum().value_counts()
cat_rank[:15]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-70ea3aab3db4> in <module>
# ----> 1 cat_rank = log_dff.groupby(['uid', 'action_type']).category1.sum().value_counts()
#       2 cat_rank[:15]
#
# NameError: name 'log_dff' is not defined

# %%
# case1 . 가구
filter = (log_dff.category1 == '가구')

# %%
log_dff_furn = log_dff.loc[filter,:] #loc

# %%
grouped = log_dff_furn.groupby(['uid','action_type'])['collect_time'].min() # 시간에 대해 최초접속을 기준으로 하기 위해 min으로 정렬
funnel_steps = pd.DataFrame({'steps':[1,2,3]}, index = ['View','Highlight','Basket'])
grouped = pd.DataFrame(grouped).merge(funnel_steps , left_on = 'action_type', right_index = True)
funnel = grouped.reset_index().pivot(index='uid', columns = 'steps', values = 'collect_time')
funnel.columns = funnel_steps.index
step_values = [funnel[column].notnull().sum() for column in funnel.columns]
step_values
# Out:
# [235500, 21931, 14252]

# %%
import plotly.express as px
data = dict(
    number = step_values,
    stage = ['View','Highlight','Basket']) #기업의 입장에서 이상적인 route 로 가정하고 둔 구간.
fig = px.funnel(data, x = 'number', y='stage')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d7eb04c6-ba66-4aab-afef-6ff773671110" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7eb04c6-ba66-4aab-afef-6ff773671110")) {                    Plotly.newPlot(                        "d7eb04c6-ba66-4aab-afef-6ff773671110",                        [{"hovertemplate":"number=%{x}<br>stage=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","orientation":"h","showlegend":false,"x":[235500,21931,14252],"xaxis":"x","y":["View","Highlight","Basket"],"yaxis":"y","type":"funnel"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"s ...

# %%
print(np.mean(abs(funnel['View']- funnel['Highlight'])))
print(np.mean(abs(funnel['Highlight'] - funnel['Basket'])))
print(np.mean(abs(funnel['View'] - funnel['Basket'])))
# Out:
# 0 days 13:17:05.896239974
# 0 days 14:15:31.245753715
# 0 days 13:14:34.504288043

# %%
# case2. (log_dff.category1 == '가전·디지털')

# %%
filter = (log_dff.category1 == '가전·디지털')

# %%
log_dff_digital = log_dff.loc[filter,:]

# %%
grouped = log_dff_digital.groupby(['uid','action_type'])['collect_time'].min() # 시간에 대해 최초접속을 기준으로 하기 위해 min으로 정렬
funnel_steps = pd.DataFrame({'steps':[1,2,3]}, index = ['View','Highlight','Basket'])
grouped = pd.DataFrame(grouped).merge(funnel_steps , left_on = 'action_type', right_index = True)
funnel = grouped.reset_index().pivot(index='uid', columns = 'steps', values = 'collect_time')
funnel.columns = funnel_steps.index
step_values = [funnel[column].notnull().sum() for column in funnel.columns]
step_values
# Out:
# [110132, 10598, 4217]

# %%
print(np.mean(abs(funnel['View']- funnel['Highlight'])))
print(np.mean(abs(funnel['Highlight'] - funnel['Basket'])))
print(np.mean(abs(funnel['View'] - funnel['Basket'])))
# Out:
# 0 days 08:48:09.694321859
# 0 days 11:57:55.089771891
# 0 days 10:21:40.245510455

# %%
# case3. (log_dff.category1 == '노하우')

# %%
filter = (log_dff.category1 == '노하우')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f12df3898760> in <module>
# ----> 1 filter = (log_dff.category1 == '노하우')
#
# NameError: name 'log_dff' is not defined

# %%
log_dff_nohow = log_dff.loc[filter,:]
log_dff_nohow
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-156-5246ace4522e> in <module>
#       1 log_dff_nohow = log_dff.loc[filter,:]
# ----> 2 log_dff_nohow.sum().unique()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10706             **kwargs,
#   10707         ):
# > 10708             return NDFrame.sum(
#   10709                 self, axis, skipna, level, numeric_only, min_count, **kwargs
#   10710             )
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10444         **kwargs,
#   10445     ):
# > 10446         return self._min_count_stat_function(
#   10447             "sum", nanops.nansum, axis, skipna, level, numeric_only, min_count, **kwargs
#   10448         )
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in _min_count_stat_function(self, name, func, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10426                 numeric_only=numeric_only,
#   10427             )
# > 10428         return self._reduce(
#   10429             func,
#   10430             name=name,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    9849             # After possibly _get_data and transposing, we are now in the
#    9850             #  simple case where we can use BlockManager.reduce
# -> 9851             res, _ = df._mgr.reduce(blk_func, ignore_failures=ignore_failures)
#    9852             out = df._constructor(res).iloc[0]
#    9853             if out_dtype is not None:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/managers.py in reduce(self, func, ignore_failures)
#    1281         res_blocks: list[Block] = []
#    1282         for blk in self.blocks:
# -> 1283             nbs = blk.reduce(func, ignore_failures)
#    1284             res_blocks.extend(nbs)
#    1285
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py in newfunc(self, *args, **kwargs)
#     139         else:
#     140             # Split and operate column-by-column
# --> 141             return self.split_and_operate(meth, *args, **kwargs)
#     142
#     143     return cast(F, newfunc)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py in split_and_operate(self, func, *args, **kwargs)
#     503         res_blocks = []
#     504         for nb in self._split():
# --> 505             rbs = func(nb, *args, **kwargs)
#     506             res_blocks.extend(rbs)
#     507         return res_blocks
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py in reduce(self, func, ignore_failures)
#    1807
#    1808         try:
# -> 1809             res = func(self.values)
#    1810         except TypeError:
#    1811             if not ignore_failures:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in blk_func(values, axis)
#    9821                 return values._reduce(name, skipna=skipna, **kwds)
#    9822             else:
# -> 9823                 return op(values, axis=axis, skipna=skipna, **kwds)
#    9824
#    9825         def _get_data() -> DataFrame:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      92             try:
#      93                 with np.errstate(invalid="ignore"):
# ---> 94                     return f(*args, **kwargs)
#      95             except ValueError as e:
#      96                 # we want to transform an object array
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     409             mask = isna(values)
#     410
# --> 411         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     412
#     413         if datetimelike:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/nanops.py in nansum(values, axis, skipna, min_count, mask)
#     589         dtype_sum = np.float64  # type: ignore[assignment]
#     590
# --> 591     the_sum = values.sum(axis, dtype=dtype_sum)
#     592     the_sum = _maybe_null_out(the_sum, axis, mask, values.shape, min_count=min_count)
#     593
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      49
#      50 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# KeyboardInterrupt:

# %%
grouped = log_dff_nohow.groupby(['uid','action_type'])['collect_time'].min() # 시간에 대해 최초접속을 기준으로 하기 위해 min으로 정렬
funnel_steps = pd.DataFrame({'steps':[1,2,3]}, index = ['View','Highlight','Basket'])
grouped = pd.DataFrame(grouped).merge(funnel_steps , left_on = 'action_type', right_index = True)
funnel = grouped.reset_index().pivot(index='uid', columns = 'steps', values = 'collect_time')
funnel.columns = funnel_steps.index
step_values = [funnel[column].notnull().sum() for column in funnel.columns]
step_values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-153-d6a090432e89> in <module>
#       3 grouped = pd.DataFrame(grouped).merge(funnel_steps , left_on = 'action_type', right_index = True)
#       4 funnel = grouped.reset_index().pivot(index='uid', columns = 'steps', values = 'collect_time')
# ----> 5 funnel.columns = funnel_steps.index
#       6 step_values = [funnel[column].notnull().sum() for column in funnel.columns]
#       7 step_values
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
#     767         self._clear_item_cache()
#     768
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     214     def set_axis(self, axis: int, new_labels: Index) -> None:
#     215         # Caller is responsible for ensuring we have an Index object.
# --> 216         self._validate_set_axis(axis, new_labels)
#     217         self.axes[axis] = new_labels
#     218
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
#      55
#      56         elif new_len != old_len:
# ---> 57             raise ValueError(
#      58                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      59                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 2 elements, new values have 3 elements

# %%
rank_cate = ['가구','가전·디지털','가구가구','패브릭','주방용품','데코·식물','생활용품','수납·정리','가전·디지털가전·디지털']

# %%
for cate in rank_cate:
  filter = (log_dff.category1 == cate)

  log_dff_cate = log_dff.loc[filter, :]

  grouped = log_dff_cate.groupby(['uid','action_type'])['collect_time'].min() # 시간에 대해 최초접속을 기준으로 하기 위해 min으로 정렬
  funnel_steps = pd.DataFrame({'steps':[1,2,3]}, index = ['View','Highlight','Basket'])
  grouped = pd.DataFrame(grouped).merge(funnel_steps , left_on = 'action_type', right_index = True)
  funnel = grouped.reset_index().pivot(index='uid', columns = 'steps', values = 'collect_time')
  funnel.columns = funnel_steps.index
  step_values = [funnel[column].notnull().sum() for column in funnel.columns]
  print(step_values)
# Out:
# [235500, 21931, 14252]
# [110132, 10598, 4217]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'uid'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-146-591dc725f63f> in <module>
#       7   funnel_steps = pd.DataFrame({'steps':[1,2,3]}, index = ['View','Highlight','Basket'])
#       8   grouped = pd.DataFrame(grouped).merge(funnel_steps , left_on = 'action_type', right_index = True)
# ----> 9   funnel = grouped.reset_index().pivot(index='uid', columns = 'steps', values = 'collect_time')
#      10   funnel.columns = funnel_steps.index
#      11   step_values = [funnel[column].notnull().sum() for column in funnel.columns]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    7791         from pandas.core.reshape.pivot import pivot
#    7792
# -> 7793         return pivot(self, index=index, columns=columns, values=values)
#    7794
#    7795     _shared_docs[
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     501             index_list = [Series(data.index, name=data.index.name)]
#     502         else:
# --> 503             index_list = [data[idx] for idx in com.convert_to_list_like(index)]
#     504
#     505         data_columns = [data[col] for col in columns_listlike]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/pivot.py in <listcomp>(.0)
#     501             index_list = [Series(data.index, name=data.index.name)]
#     502         else:
# --> 503             index_list = [data[idx] for idx in com.convert_to_list_like(index)]
#     504
#     505         data_columns = [data[col] for col in columns_listlike]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'uid'

# %% [markdown]
# 함수화 시키자

# %% [markdown]
# -------------------------

# %%
log_dff[log_dff['action_type'] == 'View'].nunique()
# Out:
# collect_time    679385
# uid             646676
# action_type          1
# category1         3135
# dtype: int64

# %%
log_dff[log_dff['action_type'] == 'View'].groupby(['funnel']).nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-ce143b3f42d3> in <module>
# ----> 1 log_dff[log_dff['action_type'] == 'View'].groupby(['funnel']).nunique()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     887             from pandas.core.groupby.grouper import get_grouper
#     888
# --> 889             grouper, exclusions, obj = get_grouper(
#     890                 obj,
#     891                 keys,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     860                 in_axis, level, gpr = False, gpr, None
#     861             else:
# --> 862                 raise KeyError(gpr)
#     863         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     864             # Add key to exclusions
#
# KeyError: 'funnel'

# %% [markdown]
# ### 일별 or 시간별 주요통계
# - 주요 화면의 빈도를 구함으로써 앱의 사용성 패턴을 보기위함
# - 일별, 요일별 데이터 빈도 및 증감의 패턴
# - 시간변수와 uid, 그리고 카테고리별 변수의(피벗) 상호작용

# %% [markdown]
# ####  Category 1 별로 view -> basket 어디가 짧은지 ?
#
# *   접근 소요 시간
#
# (10개만 추려서 한다던지)  : Insight를 찾기위해

# %%
log_dff = log_drop_null[['collect_time', 'uid', 'action_type', 'category1']].copy()

# %%
log_dff
# Out:
#                collect_time               uid action_type category1
# 479048  2022-12-22 00:00:00  PUiJdmOi9ZcADXtx        View        가구
# 3893008 2022-12-22 00:00:01  Pf2LhGOjGFEADj1W   Highlight        조명
# 185259  2022-12-22 00:00:01            unname        View        가구
# 132990  2022-12-22 00:00:01  ch2Z1WDxeWsADNoO        View        가구
# 4892838 2022-12-22 00:00:01  Ok/iZGNvpQIADwDS   Highlight        가구
# ...                     ...               ...         ...       ...
# 5574023 2022-12-30 13:59:59  07idymOQWBQABDlw        Copy       패브릭
# 3592283 2022-12-30 13:59:59  fYx4OGN0PJUACMDT        View       패브릭
# 5561628 2022-12-30 13:59:59  diIj92OSuiwACGvT        View      주방용품
# 5611799 2022-12-30 13:59:59  avXigmJ8inIAAe8q        View     데코·식물
# 5609974 2022-12-30 13:59:59  PWmyWWLCQaIACian        View    가전·디지털
#
# [4671060 rows x 4 columns]

# %%
min_grouped = log_dff.groupby(['uid','action_type','category1'])['collect_time'].min()
min_grouped
# Out:
# uid               action_type  category1
# 0++3ZGK1UAwAADb+  View         노하우         2022-12-28 15:20:39
#                                주방용품        2022-12-28 15:56:06
# 0+0E1GJwuzsACQ83  Highlight    패브릭         2022-12-28 20:01:45
#                   View         패브릭         2022-12-28 19:53:21
# 0+0E1GOjv/8ABjEM  View         데코·식물       2022-12-22 11:28:36
#                                                    ...
# ztssBGDawzIADCeb  View         노하우         2022-12-26 08:54:34
# zwYvtWOl6NgADWlA  View         가전·디지털      2022-12-24 02:45:10
# zyaeLmOs57EACT8n  View         노하우         2022-12-29 10:05:15
# zyak/GLq3i0ACWBJ  View         가구          2022-12-30 10:56:45
#                                조명          2022-12-30 10:56:40
# Name: collect_time, Length: 1086743, dtype: datetime64[ns]

# %%
max_grouped = log_dff.groupby(['uid','action_type','category1'])['collect_time'].max()
max_grouped
# Out:
# uid               action_type  category1
# 0++3ZGK1UAwAADb+  View         노하우         2022-12-28 16:12:56
#                                주방용품        2022-12-28 15:56:06
# 0+0E1GJwuzsACQ83  Highlight    패브릭         2022-12-28 20:01:45
#                   View         패브릭         2022-12-28 19:59:07
# 0+0E1GOjv/8ABjEM  View         데코·식물       2022-12-22 11:28:36
#                                                    ...
# ztssBGDawzIADCeb  View         노하우         2022-12-26 08:54:34
# zwYvtWOl6NgADWlA  View         가전·디지털      2022-12-24 02:45:10
# zyaeLmOs57EACT8n  View         노하우         2022-12-29 10:05:15
# zyak/GLq3i0ACWBJ  View         가구          2022-12-30 10:57:06
#                                조명          2022-12-30 11:02:31
# Name: collect_time, Length: 1086743, dtype: datetime64[ns]

# %%
# sum_value_counts 한것에서 상위 몇개만 뽑아
# 가구, 가전/디지털, 노하우 , 패브릭 , 주방용품 , 데코/식물 , 생활용품, 수납.정리 
grouped = log_dff.groupby(['uid','action_type'])['category1'].sum().value_counts()
grouped
# Out:
# 가구                                                                             101356
# 가전·디지털                                                                          55643
# 노하우                                                                             43651
# 가구가구                                                                            34265
# 패브릭                                                                             31011
#                                                                                 ...
# 패브릭가구생활용품수납·정리수납·정리생활용품                                                             1
# 가구팔로모팔로모팔로모팔로모팔로모팔로모팔로모팔로모팔로모팔로모가구                                                  1
# 주방용품주방용품패브릭가구생활용품생활용품생활용품생활용품생활용품생활용품생활용품생활용품생활용품생활용품생활용품가구가구가구가구가구가구가구가구가구         1
# 패브릭패브릭패브릭패브릭패브릭패브릭패브릭패브릭패브릭패브릭가구가구가구가구가구가구가구패브릭패브릭패브릭패브릭패브릭패브릭가구                    1
# 반려동물반려동물데코·식물패브릭반려동물주방용품주방용품패브릭                                                     1
# Name: category1, Length: 91193, dtype: int64

# %%
log_dff.groupby(['collect_time','category1']).size().unstack().dropna(axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-55ffe7b840f3> in <module>
# ----> 1 log_dff.groupby(['collect_time','category1']).size().unstack().dropna(axis=1)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in unstack(self, level, fill_value)
#    4079         from pandas.core.reshape.reshape import unstack
#    4080
# -> 4081         return unstack(self, level, fill_value)
#    4082
#    4083     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value)
#     458         if is_1d_only_ea_dtype(obj.dtype):
#     459             return _unstack_extension_series(obj, level, fill_value)
# --> 460         unstacker = _Unstacker(
#     461             obj.index, level=level, constructor=obj._constructor_expanddim
#     462         )
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/reshape.py in __init__(self, index, level, constructor)
#     129
#     130         if num_rows > 0 and num_columns > 0 and num_cells <= 0:
# --> 131             raise ValueError("Unstacked DataFrame is too big, causing int32 overflow")
#     132
#     133         self._make_selectors()
#
# ValueError: Unstacked DataFrame is too big, causing int32 overflow

# %%
log_dff.groupby('collect_time').size()

s = log_dff.groupby('collect_time')['uid'].nunique()
s.index = s.index.dayofweek

s.plot(color ='grey', kind= 'bar', rot=0);
plt.title("Daily Session")
plt.tight_layout()

# %% [markdown]
# ### 구간별 전환율 구하기
#
# - 주요 구간 설정
# - 전환율 수식 적용
#
#
#
# ### 클러스터 별 전환율 차이
