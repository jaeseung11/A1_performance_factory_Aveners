# %%
import pandas as pd
import numpy as np

from pathlib import Path

# %%
BASE_DIR = Path(__name__).resolve().parent.parent
FILES_DIR = BASE_DIR / 'files'

# %%
bidding = pd.read_csv(FILES_DIR / 'bidding_results.csv')
log = pd.read_csv(FILES_DIR / 'log_csv.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1448\1994602942.py in <module>
# ----> 1 bidding = pd.read_csv(FILES_DIR / 'bidding_results.csv')
#       2 log = pd.read_csv(FILES_DIR / 'log_csv.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'files\\bidding_results.csv'

# %%
bidding
# Out:
#            index  Impression  Click   Cost  Sum of AD rank  Bid  Price(PC)  \
# 0        3575092           3      0    0.0        3.000000   50     165900
# 1        3575637           6      0    0.0        3.333333   50      10900
# 2        4129259           7      0    0.0        8.000000   50     255000
# 3        4131479          36      3  150.0        4.416667  140     190000
# 4        4131482         224      0    0.0        5.696429   50     129000
# ...          ...         ...    ...    ...             ...  ...        ...
# 1337083  2566795           5      0    0.0       13.200000  500      19900
# 1337084  2566880           3      0    0.0       17.000000  500      23900
# 1337085  2566881           1      0    0.0        8.000000  500       2500
# 1337086  2566891           2      0    0.0        4.000000  500      21000
# 1337087  2566923          14      0    0.0       12.428571  500     128800
#
#          Price(Mobile)  Delivery Fee Category Name 1 Category Name 2  \
# 0               165900             0         가구/인테리어            침실가구
# 1                10900             0         가구/인테리어          인테리어소품
# 2               255000            -1         가구/인테리어            거실가구
# 3               190000         20000         가구/인테리어        아동/주니어가구
# 4               129000             0         가구/인테리어        아동/주니어가구
# ...                ...           ...             ...             ...
# 1337083          19900             0         가구/인테리어          인테리어소품
# 1337084          23900          3000           생활/건강         문구/사무용품
# 1337085           2500          3000         가구/인테리어          인테리어소품
# 1337086          21000          3000           생활/건강         정원/원예용품
# 1337087         128800             0         가구/인테리어          인테리어소품
#
#         Category Name 3 Category Name 4      date
# 0               장롱/붙박이장            드레스룸  20221031
# 1              아로마/캔들용품      아로마방향제/디퓨저  20221031
# 2                    소파           패브릭소파  20221031
# 3                책상의자세트             NaN  20221031
# 4                    책상             NaN  20221031
# ...                 ...             ...       ...
# 1337083        아로마/캔들용품      아로마방향제/디퓨저  20230103
# 1337084        이벤트/파티용품            데코용품  20230103
# 1337085          기타장식용품             NaN  20230103
# 1337086            화분받침             NaN  20230103
# 1337087              액자      퍼즐/그림/사진액자  20230103
#
# [1337088 rows x 14 columns]

# %% [markdown]
# ### Bidding

# %%
indexs = list(set(bidding['index'].to_list()))
print(len(indexs))
# Out:
# 48896

# %%
categorys = list(set(bidding['Category Name 1'].to_list()))
categorys
# Out:
# ['식품',
#  '디지털/가전',
#  '생활/건강',
#  '가구/인테리어',
#  '여가/생활편의',
#  '패션잡화',
#  '스포츠/레저',
#  '화장품/미용',
#  '패션의류',
#  '출산/육아']

# %%
idx_distinct_df = bidding.drop_duplicates(['index'])

# %%
idx_distinct_df['Category Name 1'].value_counts(dropna=True)
# Out:
# 가구/인테리어    34629
# 생활/건강      11827
# 출산/육아        940
# 스포츠/레저       578
# 화장품/미용       305
# 패션잡화         276
# 디지털/가전       184
# 패션의류         122
# 여가/생활편의       27
# 식품             8
# Name: Category Name 1, dtype: int64

# %%
for cate in categorys:
    df = idx_distinct_df.loc[idx_distinct_df['Category Name 1'] == cate]
    print(f"{cate}: {df['Click'].sum()}")
# Out:
# 식품: 0
# 디지털/가전: 223
# 생활/건강: 9075
# 가구/인테리어: 17113
# 여가/생활편의: 51
# 패션잡화: 184
# 스포츠/레저: 796
# 화장품/미용: 224
# 패션의류: 167
# 출산/육아: 1346

# %%
for cate in categorys:
    df = idx_distinct_df.loc[idx_distinct_df['Category Name 1'] == cate]
    print(f"{cate}: {df['Impression'].sum()}")
# Out:
# 식품: 101
# 디지털/가전: 11664
# 생활/건강: 458140
# 가구/인테리어: 1101372
# 여가/생활편의: 3936
# 패션잡화: 9828
# 스포츠/레저: 40037
# 화장품/미용: 11810
# 패션의류: 6660
# 출산/육아: 54193

# %%
for cate in categorys:
    df = idx_distinct_df.loc[idx_distinct_df['Category Name 1'] == cate]
    print(f"{cate}: {df['Cost'].sum()}")
# Out:
# 식품: 0.0
# 디지털/가전: 28220.0
# 생활/건강: 2505070.0
# 가구/인테리어: 5399690.0
# 여가/생활편의: 5330.0
# 패션잡화: 47040.0
# 스포츠/레저: 180510.0
# 화장품/미용: 79540.0
# 패션의류: 68440.0
# 출산/육아: 248940.0

# %%
for cate in categorys:
    df = idx_distinct_df.loc[idx_distinct_df['Category Name 1'] == cate]
    print(f"{cate}: {df['Bid'].sum()}")
# Out:
# 식품: 2200
# 디지털/가전: 29280
# 생활/건강: 2602920
# 가구/인테리어: 6643320
# 여가/생활편의: 4090
# 패션잡화: 61620
# 스포츠/레저: 128640
# 화장품/미용: 87100
# 패션의류: 14300
# 출산/육아: 234490

# %%
for cate in categorys:
    df = idx_distinct_df.loc[idx_distinct_df['Category Name 1'] == cate]
    print(f"{cate}: PC: {df['Price(PC)'].sum()}, Mobile: {df['Price(Mobile)'].sum()}")
# Out:
# 식품: PC: 144700, Mobile: 144700
# 디지털/가전: PC: 7777378, Mobile: 7777378
# 생활/건강: PC: 414339829, Mobile: 414339829
# 가구/인테리어: PC: 7900671059, Mobile: 7900671059
# 여가/생활편의: PC: 3050240, Mobile: 3050240
# 패션잡화: PC: 5653030, Mobile: 5653030
# 스포츠/레저: PC: 49548785, Mobile: 49548785
# 화장품/미용: PC: 9481455, Mobile: 9481455
# 패션의류: PC: 4459740, Mobile: 4459740
# 출산/육아: PC: 65058680, Mobile: 65058680

# %%
idx_distinct_df.loc[idx_distinct_df['Click'] == 0]['Cost'].sum()
# Out:
# 0.0

# %%
idx_distinct_df.sort_values(by=['Click'], ascending=False).loc[idx_distinct_df['Click'] > 0]
# Out:
#            index  Impression  Click      Cost  Sum of AD rank   Bid  \
# 122274   1652151       13460    361  126670.0        1.233804   500
# 289756   3510537       14965    275   86690.0        1.836619    50
# 229463   6350550        6716    147   98730.0        2.106909  1000
# 10371    3763358       11322    145   19000.0        1.017488   300
# 314429   3510568        5141    136   55350.0        1.041626    50
# ...          ...         ...    ...       ...             ...   ...
# 865814   8816404          63      1     390.0        5.269841   500
# 1056882    53617          85      1     200.0        1.000000   500
# 1112996  1322672          20      1     120.0        2.000000   500
# 7523      517450          23      1      50.0        8.695652    50
# 5252     8131223          11      1      50.0        6.090909    50
#
#          Price(PC)  Price(Mobile)  Delivery Fee Category Name 1  \
# 122274      399000         399000             0           생활/건강
# 289756      117900         117900             0           생활/건강
# 229463      189000         189000             0         가구/인테리어
# 10371       334010         334010             0          스포츠/레저
# 314429      539000         539000             0           생활/건강
# ...            ...            ...           ...             ...
# 865814      289000         289000            -1         가구/인테리어
# 1056882      31500          31500          2900           생활/건강
# 1112996      25000          25000          3000           생활/건강
# 7523        129000         129000            -1         가구/인테리어
# 5252         89900          89900            -1         가구/인테리어
#
#         Category Name 2 Category Name 3 Category Name 4      date
# 122274          문구/사무용품        다이어리/플래너          캘린더/달력  20221108
# 289756          문구/사무용품        다이어리/플래너          캘린더/달력  20221116
# 229463         서재/사무용가구              의자           목받침의자  20221114
# 10371                캠핑            캠핑가구           캠핑테이블  20221031
# 314429          문구/사무용품        다이어리/플래너          캘린더/달력  20221117
# ...                 ...             ...             ...       ...
# 865814             주방가구           식탁/의자            식탁세트  20221212
# 1056882           원예/식물              조화             NaN  20221219
# 1112996            주방용품            주방잡화              쟁반  20221226
# 7523           서재/사무용가구              책상           독서실책상  20221031
# 5252               침실가구             화장대           일반화장대  20221031
#
# [9617 rows x 14 columns]

# %% [markdown]
# ### Log

# %%
log
# Out:
#          Unnamed: 0               uid action_type category1  category2  \
# 0                 0  avpKyWMn/xEADNlb        View      주방용품     그릇·홈세트
# 1                 1  0+5vEmGkOuAAB5j2      Basket       패브릭         매트
# 2                 2  r8DXy2OtSl8AAojG        View       패브릭     커튼·부자재
# 3                 3  dC9Fl2Ly9lcADrTn   Highlight     데코·식물     플라워·식물
# 4                 4  09gKcGLg0I8ACyQy        View        가구     진열장·책장
# ...             ...               ...         ...       ...        ...
# 5659536     5659536  PUpxWWMWdcIACR2B        View      주방용품     칼·커팅기구
# 5659537     5659537  PVMstmNg4I4ADq9R      Basket        가구     진열장·책장
# 5659538     5659538  diRXdmN49dUABrVo        View        가구  테이블·식탁·책상
# 5659539     5659539  dusFzWJvp5cADhZW        View    가전·디지털       계절가전
# 5659540     5659540  bgy5ZGOszc4ADrmd        View        가구     화장대·콘솔
#
#          category3         collect_time geoip_city_name useragent_os  \
# 0          식판·나눔접시  2022-12-29 17:29:02     Seongnam-si      Windows
# 1         주방·다용도매트  2022-12-29 12:56:38       Yongin-si      Windows
# 2             암막커튼  2022-12-29 17:11:30           Seoul          iOS
# 3            화병·화분  2022-12-29 17:54:30  Gwangmyeong-si      Windows
# 4               책장  2022-12-29 18:45:05       Jongno-gu     Mac OS X
# ...            ...                  ...             ...          ...
# 5659536  채칼·다지기·강판  2022-12-28 20:01:30           Seoul      Android
# 5659537         책장  2022-12-28 14:30:09           Jinju      Windows
# 5659538         식탁  2022-12-29 12:45:13           Gunpo      Android
# 5659539   전기히터·온풍기  2022-12-28 11:07:30           Seoul      Android
# 5659540      일반화장대  2022-12-29 08:14:39           Iksan          iOS
#
#          viewrate  viewtime
# 0           100.0     80033
# 1             0.0         0
# 2           100.0       947
# 3             0.0         0
# 4           100.0      1238
# ...           ...       ...
# 5659536     100.0     13893
# 5659537       0.0         0
# 5659538     100.0     47217
# 5659539     100.0     54030
# 5659540       0.0         0
#
# [5659541 rows x 11 columns]

# %%
uid_distinct_df = log.drop_duplicates(['uid'])

# %%
# 유저 수
uids = list(set(log['uid'].to_list()))
print(len(uids))
# Out:
# 828537

# %%
devices = list(set(log['useragent_os'].to_list()))
devices
# Out:
# ['Windows',
#  'Tizen',
#  'Other',
#  'Ubuntu',
#  'Chrome OS',
#  'Fedora',
#  'Mac OS X',
#  'iOS',
#  'FreeBSD',
#  'OpenBSD',
#  'Linux',
#  'Android',
#  'CentOS']

# %%
for device in devices: 
    df = uid_distinct_df.loc[uid_distinct_df['useragent_os'] == device]
    print(f"{device}: {df['useragent_os'].count()}")
# Out:
# Windows: 296104
# Tizen: 21
# Other: 958
# Ubuntu: 36
# Chrome OS: 127
# Fedora: 2
# Mac OS X: 29204
# iOS: 173581
# FreeBSD: 1
# OpenBSD: 1
# Linux: 1892
# Android: 326563
# CentOS: 47

# %%
action_types = list(set(log['action_type'].to_list()))
action_types
# Out:
# ['Copy', 'Highlight', 'SINF', 'View', 'Basket']

# %%
for _type in action_types:  
    df = uid_distinct_df.loc[uid_distinct_df['action_type'] == _type]
    print(f"{_type}: {df['action_type'].count()}")
# Out:
# Copy: 3203
# Highlight: 19148
# SINF: 4485
# View: 794961
# Basket: 6740

# %%
categorys = list(set(log['category1'].to_list()))
print(len(categorys))
print(categorys)
# Out:
# 3373
# ['소소콤마', '리빙디오', '루나랩 홈', '카스', '팔로모', '収納・整理', '마티노가구', '레트로하우스', '싱글맨션', '쁘띠도그', '예다움', 'ファブリック ', '사토가구', '포트메리온', '파워플랜트', 'HIFI', 'blanc deco', '크렌시아', '냥품멍품', ' 한샘', '힐링쉴드', '라이크 커머스', '쿡샵', 'RCR', '마리메종', '우아미가구', '프라우반', '바로방가구', 'DIYSTORY', '인디케이', '앨리스가든', '글로잉컬러', '그로브메이드', '펠리스침대', '앱코', '밴프', 'Decor Plantă', '베터핑거', '모콘디자인', '소피아엘렌', '라이프시리즈', '민무니', '다솜다솜', '오홀리브', '厨房装修', '인화전기', '이우아여사', '루비코코', '보루네오', '체리쉬', '빌리노어', '스마일델리', '비셀리움', '참라이팅', '에쿤', '코베아', '디지우드', '엄마가구', '룸스토어', '만개잡화점', '베디스', '메세라미카', '보국전자', '동화속나무', '네스프레소', '자주', '포레울', '딩동펫', '프랭클리슬리핑', '조하', 'Herman Miller', 'Thông tin tri thức ', '레이베스', '잇워즈유', '바른닥터', '센토키즈', '코세드', 'FDF개비', '애슐리 홈스토랑', '타공판나라', '설렘하우스', '자네트가구', '마블앤테이블', '크로노', '모즈', '스카이보틀', '캔수', '젊은이마켓', '소소숲', '아름이와다움이', '눌세라믹', '아이엔지홈', '이케아', '와우숍', '로이첸', '씨에스리빙', '모노', '구룸아카이브', '키키친', '쇼트즈위젤', '노하우', '리우리빙', '식스티세컨즈', '모두의러그', '루나스퀘어', '오트밀하우스', '퍼플뉴퍼니처', '바이아미', '우드토픽', '비비앤데이', '히토리', '이브리영', '비츠', '다니엘우드', '메이쥬아', '라임올리브', '올리그로우', '가본조명', '하이앤드리', '드로잉엣홈', '하지트', 'кухонные принадлежности', '아우어데이즈', '핀블랑', '셈프레샵', '퍼시스', '레뮤', '레나비', '늘하우스', '썸앤데코', '290wood', '올댓하우스', '세비앙', '앙플랜트', '퍼니매스', '아이리스코리아', 'DELI', '더쎈', '쟈스민갤러리', '엑토', '도잠', '데스커', '노바리빙', 'market fee', '오키멧', '퍼니비', '메종드블랑', '식품', '까사루이', '이정가구', '한일스텐레스', '제이준편백', '꼬메모이', '어긋난몰', '오브바이포', '비페이퍼', '차밍데코', '버즈가구', '라메종하우스', '라마하트', '미스터맙', '문스타', '모던트', '브라이튼', '르모트', '생활양식', '지퍼락', '땡큐마더', '프레시지', '배러덴홈', '닷홈', '마리메꼬', '티에스퍼니처', '아르페지오', '온미러', '지오플래닛', '햄튼', '드플레잉', '마롱즈', '마요하', '정리생활', '베베앙', '우드렌', '幼児・児童', '터리빙', '보아르', '한일홈', '다이소', '이홈데코', '오션글라스', '피플랜트', '장인가구', '비비홈', '디센', '러그룸', '솔라콤', '프티트리아농', 'POH', '生活用品', '이이공브이샵', 'FREESPACE', '허글', '리빙앤소품', '이노센트', '오이오이(OYOY)', '크로우캐년', 'کالاهای خانگی', '한경희생활과학', '엣지퍼니처', 'JD홈드레싱', '에이치앤아이', '카카오프렌즈', '아는친구네', 'YOMI', '헤르짐머', 'GSS', '큐브', '일일일상', '우드하임', '마루이', 'alias', '嬰兒 兒童', '글라스터', '샵베딩', '로드98', '인블룸', '악당스토어', '카펫테리아', '디에이트', '옐로우라이트', 'feel', '디에프퍼니처', '타카타카', '니드코', '키친팩토리', '제너', 'marui', '올리비아데코', '아트유', '코지샵', 'ノウハウ', '올쏘퍼니처', '루악오디오', '그남자의가구홈데코', 'JMW', '구스퍼니처', '하이플러스가구', '5월의일상', '베이비빈즈', '엠디자인', '하우스팁', 'OMT', '픽브릿지', 'LG전자', '아파트32 홈', '슈렉앳홈', '소노시즌', '레이브', 'VOHE', '도아르가구', '포메리트', '에어론', '살림취향집', '퀸센스', 'Geek', 'NHB', '우리집풍경', '모월', '블로무스', '하울스홈', '블립', '탈로리피', '심플리에', '메종수피아', '브리스크스타일', '펠리토', '깔끔상회', '해피데이 ', '아이자와공방', '힘찬리빙', '30sense', 'PAGE127', '제니아테일러', '카루셀리', '르토이반', '유즈', 'daily necessity', '쿠션이야기', '릴리캐비넷', '주앤지', '리플레이스', '밀크바오밥', '머블', 'opertum', '더리드', '에듀테인', '베이메이트', '솔러스에어', '브라운', '드롱기', 'LG', '데코지오', '레보떼', '모든집', '라리사', '올썸', '라움스튜디오', '미즈하우스', '쌍수동', '힐링가구', '노르딕네스트', '바솔트홈', '가구모티브', '로지텍', '한성컴퓨터', '조앤레아', '아츠리프', '그리고 낭만', '라세라미끄', '핸드메이드썸', '모던하우스', '오이시이키친', '지베스', '아름드리', '휴앤봇', '원스톱퍼니처', '家电 数码', '이에스알', '샐마', 'ZARA HOME', '영이오브제', '앙비까사', '미아트', '퀸하우징', 'OYOY', '공간LED', '고려가구', '롯데알미늄', '스누피', 'Depolama, organizasyon', '라메종베르트', 'Know-how ', '츠바메', '리에르스튜디오', '퍼니츠', '의자왕', '썬데이감성', '비알프렌드', '블랑데코', '지프', '십이월삼일', '페페무드', '유닉스', '리빙하우스', 'Ev eşyaları', 'deco and plants', '다루미', 'HAEGANG', '미드센추리', '용이네화원', '레이디가구', '드리움', '포그니아 ', '시프트', '아티바움', '픽홈', '리빙스토어', '부자오빠', '스토움', '헬로우슬립', '모던한잡화점', '어썸프레임', '이스플리', '달퐁이네 문방구', '식탁연구소', '코아스', '어나더어스', '무니토', '쿠나장롱', '에드펩', '이안비즈', '렛씨온니굿띵', '소미랑', '에몬스', '레노벨로', 'classicon', 'depound(드파운드)', '모비가든', '헤리터', '네스홈', '코지코튼', '메이크정글', '라이프디바니', '16피스', '프리즘코리아', '커스텀아크릴', '리프리홈', '누보데코', '오리엔탈무드', '파티팡', '엔젤라이팅', '디자인스킨', '서진퍼니처', '하이파가구', '装饰、植物', '유한양행', 'DDWD', '로긴', '페이퍼가든', '자리스튜디오', '보넬가구', '메종드파리', '아베라주식회사', '잭슨카멜레온', '스튜디오 모쿠', '끌래망스', '하모벨', '르난세', '에코상사', '킹마담건강침대', '잘들인가구', '해찬솔원목이야기', '매스티지데코', '&tradition', '프로라이팅', '플레르샵', '하우밍', '퍼니키친', '보니타빈백', '진영가구', '헤즈로', '바네스데코', '아카시아봉봉', '바이마르', '우드블랑', '오에이데스크', '마이루미', '슈톨츠', '리체갤러리', '제퍼슨가구', '한국도자기리빙 리한', '부광약품', '브라운스타', '스피엘', '맘스보드', 'MANLAB', '제이숲', '베드앤데코', '윌파', '까사마루', '신성나라', '노만코펜하겐', '허레이', '레벤', '한국쥬맥스', '델피오레', 'Know-How ', '스칸딕퍼니처', '헤닝', '아이앤', '라이핏가구', '휘게체어', '온앤우드', '패션펫플', '클립쉬', '파뜨 ...

# %%
ips = list(set(log['geoip_city_name'].to_list()))
print(len(ips))
print(ips)
# Out:
# 3198
# [nan, 'Kitakami', 'Bolton', 'Houten', 'Havelock', 'Meizhou', 'Can Tho', 'Wilmette', 'Caloocan City', 'Zgorzelec', 'Frederick', 'Ellenwood', 'Borger', 'East York', 'Icheon-si', 'Mainz', 'Wilmington', 'Leipzig', 'Pitt Meadows', 'Bhola District', 'Nassau', 'Chisinau', 'Massy', 'Lyndhurst', 'Novorossiysk', 'Pietà', 'Valencia', 'Sao Jose do Rio Preto', 'Roswell', 'Rio de Mouro', 'Kangar', 'Westerville', 'Kuytun', 'Barra do Piraí', 'Holland', 'Pattaya', 'Gangdong-gu', 'Yongin', 'Rüsselsheim am Main', 'Elizabeth Hills', 'Yakima', 'Gresik', 'Omaha', 'Janoshaza', 'Johannesburg', 'Bhopal', 'Kalasin', 'Doha', 'Porto Moniz', 'St. Albert', 'Essen', 'Ibiuna', 'Munich', 'Iwade', 'Hortolândia', 'Denver', 'Takarazuka', 'Lyon', 'Oak Lawn', 'Bavendorf', 'Sacanta', 'Beccles', 'Inzai', 'Bella Vista', 'Bermondsey', 'Peachtree City', 'Turin', 'Delta', 'Busan', 'Sampaloc', 'Châtillon', 'Hwaseong', 'Meguro-ku', 'Walnut', 'Helvetia', 'Dnipropetrovsk', 'Heerjansdam', 'Woodhaven', 'Cheltenham', 'Desio', 'Gaithersburg', 'Flower Mound', 'Kosong', 'Busanjin-gu', 'Bedford', 'Strasbourg', 'Lanshan', 'Vienna', 'Dublin', 'Boulogne-Billancourt', 'Chusovoy', 'Northbrook', 'Tunis', 'Junggu', 'Nha Trang', 'Lakemba', 'Ernakulam', 'Karlstad', 'Gujo', 'Phu Ly', 'Belgrade', 'Ratchaburi', 'Cardiff', 'Suyeong-gu', 'Bacolod City', 'Kurye', 'Nowon-gu', 'Chichawatni', 'Curitiba', 'Alhambra', 'Carnegie', 'Geoje', 'Bell Ville', 'Tiszalok', 'Győr', 'Szczecin', 'Kushima', 'Villeurbanne', 'Melbourne', 'Go Vap', 'Temirtau', 'Chamsaemi', 'Hyoseongdong', 'Colorado Springs', 'Thu Duc', 'New Caney', 'Dziewin', 'Barnsley', 'Linhai', 'Bupyeong-gu', 'San Miguel', 'Haifa', 'Tucson', 'Hoover', 'Victoriaville', 'Belfeld', 'Little Elm', 'Voecklabruck', 'Sumida', 'Florence', 'Cheyenne', 'Ivancsa', 'Myrhorod', 'Helsinki', 'Tai Hang', 'Virginia Beach', 'Děčín', 'Jinju', 'Carmel-by-the-Sea', 'Whangarei', 'Jaboatao dos Guararapes', 'Douglasville', 'Tsukubamirai', 'St. Gallen', 'Besançon', 'Jeddah', 'Secaucus', 'Rosemead', 'New Delhi', 'Palm Beach Gardens', 'Antelope', 'Yueqing', 'Quezon City', 'Beruwala', 'Cypress', 'Saiki', 'Montpellier', 'Red Deer', 'Monrovia', 'Zurich', 'Bang Sue', 'Kampong Pasir Ris', 'Brisbane', 'Trang', 'Gheboaia', 'Mammoth Lakes', 'Kolhapur', 'Lebanon', 'Anjo', 'Banin', 'Yaroslavl', 'Thames Ditton', 'Jinan', 'Sihung', 'Heidelberg', 'Buenos Aires', 'Zhuji', 'Ingolstadt', 'Westwood', 'Hongseong', 'Tysons Corner', 'West End', 'Toyama', 'Bonito', 'Muju-gun', 'Bromborough', 'Quan Bon', 'Reykjavik', 'Iloilo City', 'Bang Bai Mai', 'Manosque', 'Batu Pahat', 'Hewitt', 'Ghulaman', 'Andong', 'Polientes', 'Edmond', 'Piscataway', 'Ganghwa-gun', 'Budapest', 'Cyberjaya', 'Hadong', 'Chula Vista', 'Pekan Baru', 'Townsville', 'Seosan City', 'Le Mars', 'Yokawacho-toyooka', 'North Wales', 'Recife', "Villeneuve-d'Ascq", 'Guangzhou', 'Newnan', 'Fujisawa', 'Eumseong-gun', 'Dulles', 'Aligarh', 'Tianjin', 'Temecula', 'Kwai Chung', 'Richmond Hill', 'Mittenwald', 'Fada', 'Yeongcheon-si', 'Mejillones', 'Newburgh', 'Changwon', 'Rubeshibecho-fujimi', 'Osasco', 'Hwasun', 'Ogaki', 'Vijayawada', 'Olympia', 'Baltimore', 'Nangen', 'Marrakesh', 'Toronto', 'Lane Cove', 'Odessa', 'San Thang', 'Belfast', 'Sargodha', 'Villemolaque', 'Mungyeong', 'Yeongdeok', 'Hida', 'Choeng Thale', 'Zhenjiang', 'Nuremberg', 'Bonghwa-gun', 'Huai Thalaeng', 'Agra', 'Si Racha', 'Muju', 'Pistoia', 'Yachiyo', 'Chang-hua', 'Taree', 'Tan Phu Hai', 'Kampong Ulu Jurong', "Rossosh'", 'Defiance', 'Suseong-gu', 'Hicksville', 'Chemnitz', 'Auterive', 'Phelan', 'Gwanak-gu', 'Alameda', 'Gondomar', 'Gonilan', 'Tenafly', 'Phitsanulok', 'Bern', 'Brossard', 'Lakewood', 'Matsudo', 'Handa', 'Dujiacun', 'Quito', 'Seongdong-gu', 'Frisco', 'Zlín', 'Kodaira', 'Hagonoy', 'Placentia', 'Roseburg', 'Abbotsford', 'Smithfield', 'Onojo', 'Dongdaemun-gu', 'Kharkiv', 'Tauranga', 'Glen Huntly', 'Naucalpan', 'Kampung Batu Kikir', 'Dreieich', 'Miami Beach', 'Laguna Niguel', 'Federal Way', 'Kalyan', 'Balch Springs', 'Nairobi', 'Cinisello Balsamo', 'San Juan', 'Thiai ...

# %%
# new_df = pd.DataFrame()
# bidding_date = set(list(bidding['date'].to_list()))

# for date in bidding_date:
#     date_df = bidding.loc[bidding['date'] == date]
#     idx_distinct_df = date_df.drop_duplicates(subset=['index'])
#     new_df = new_df.append(idx_distinct_df)
    
new_df = bidding.drop_duplicates(subset=['index', 'date'])
