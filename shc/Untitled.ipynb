# %%
import pandas as pd
import numpy as np

from pathlib import Path

# %%
BASE_DIR = Path(__name__).resolve().parent.parent
FILES_DIR = BASE_DIR / 'files'

# %%
bidding = pd.read_csv(FILES_DIR / 'bidding_results.csv')
log = pd.read_csv(FILES_DIR / 'log_csv.csv')

# %%
bidding
# Out:
#            index  Impression  Click   Cost  Sum of AD rank  Bid  Price(PC)  \
# 0        3575092           3      0    0.0        3.000000   50     165900
# 1        3575637           6      0    0.0        3.333333   50      10900
# 2        4129259           7      0    0.0        8.000000   50     255000
# 3        4131479          36      3  150.0        4.416667  140     190000
# 4        4131482         224      0    0.0        5.696429   50     129000
# ...          ...         ...    ...    ...             ...  ...        ...
# 1337083  2566795           5      0    0.0       13.200000  500      19900
# 1337084  2566880           3      0    0.0       17.000000  500      23900
# 1337085  2566881           1      0    0.0        8.000000  500       2500
# 1337086  2566891           2      0    0.0        4.000000  500      21000
# 1337087  2566923          14      0    0.0       12.428571  500     128800
#
#          Price(Mobile)  Delivery Fee Category Name 1 Category Name 2  \
# 0               165900             0         가구/인테리어            침실가구
# 1                10900             0         가구/인테리어          인테리어소품
# 2               255000            -1         가구/인테리어            거실가구
# 3               190000         20000         가구/인테리어        아동/주니어가구
# 4               129000             0         가구/인테리어        아동/주니어가구
# ...                ...           ...             ...             ...
# 1337083          19900             0         가구/인테리어          인테리어소품
# 1337084          23900          3000           생활/건강         문구/사무용품
# 1337085           2500          3000         가구/인테리어          인테리어소품
# 1337086          21000          3000           생활/건강         정원/원예용품
# 1337087         128800             0         가구/인테리어          인테리어소품
#
#         Category Name 3 Category Name 4      date
# 0               장롱/붙박이장            드레스룸  20221031
# 1              아로마/캔들용품      아로마방향제/디퓨저  20221031
# 2                    소파           패브릭소파  20221031
# 3                책상의자세트             NaN  20221031
# 4                    책상             NaN  20221031
# ...                 ...             ...       ...
# 1337083        아로마/캔들용품      아로마방향제/디퓨저  20230103
# 1337084        이벤트/파티용품            데코용품  20230103
# 1337085          기타장식용품             NaN  20230103
# 1337086            화분받침             NaN  20230103
# 1337087              액자      퍼즐/그림/사진액자  20230103
#
# [1337088 rows x 14 columns]

# %% [markdown]
# ### Bidding

# %%
indexs = list(set(bidding['index'].to_list()))
print(len(indexs))
# Out:
# 48896

# %%
categorys = list(set(bidding['Category Name 1'].to_list()))
categorys
# Out:
# ['생활/건강',
#  '패션잡화',
#  '식품',
#  '화장품/미용',
#  '가구/인테리어',
#  '디지털/가전',
#  '스포츠/레저',
#  '여가/생활편의',
#  '출산/육아',
#  '패션의류']

# %%
idx_distinct_df = bidding.drop_duplicates(['index'])

# %%
idx_distinct_df['Category Name 1'].value_counts(dropna=True)
# Out:
# 가구/인테리어    34629
# 생활/건강      11827
# 출산/육아        940
# 스포츠/레저       578
# 화장품/미용       305
# 패션잡화         276
# 디지털/가전       184
# 패션의류         122
# 여가/생활편의       27
# 식품             8
# Name: Category Name 1, dtype: int64

# %%
for cate in categorys:
    df = idx_distinct_df.loc[idx_distinct_df['Category Name 1'] == cate]
    print(f"{cate}: {df['Click'].sum()}")
# Out:
# 생활/건강: 9075
# 패션잡화: 184
# 식품: 0
# 화장품/미용: 224
# 가구/인테리어: 17113
# 디지털/가전: 223
# 스포츠/레저: 796
# 여가/생활편의: 51
# 출산/육아: 1346
# 패션의류: 167

# %%
for cate in categorys:
    df = idx_distinct_df.loc[idx_distinct_df['Category Name 1'] == cate]
    print(f"{cate}: {df['Impression'].sum()}")
# Out:
# 가구/인테리어: 1101372
# 화장품/미용: 11810
# 스포츠/레저: 40037
# 식품: 101
# 패션잡화: 9828
# 출산/육아: 54193
# 디지털/가전: 11664
# 생활/건강: 458140
# 패션의류: 6660
# 여가/생활편의: 3936

# %%
for cate in categorys:
    df = idx_distinct_df.loc[idx_distinct_df['Category Name 1'] == cate]
    print(f"{cate}: {df['Cost'].sum()}")
# Out:
# 가구/인테리어: 5399690.0
# 화장품/미용: 79540.0
# 스포츠/레저: 180510.0
# 식품: 0.0
# 패션잡화: 47040.0
# 출산/육아: 248940.0
# 디지털/가전: 28220.0
# 생활/건강: 2505070.0
# 패션의류: 68440.0
# 여가/생활편의: 5330.0

# %%
for cate in categorys:
    df = idx_distinct_df.loc[idx_distinct_df['Category Name 1'] == cate]
    print(f"{cate}: {df['Bid'].sum()}")
# Out:
# 가구/인테리어: 6643320
# 화장품/미용: 87100
# 스포츠/레저: 128640
# 식품: 2200
# 패션잡화: 61620
# 출산/육아: 234490
# 디지털/가전: 29280
# 생활/건강: 2602920
# 패션의류: 14300
# 여가/생활편의: 4090

# %%
for cate in categorys:
    df = idx_distinct_df.loc[idx_distinct_df['Category Name 1'] == cate]
    print(f"{cate}: PC: {df['Price(PC)'].sum()}, Mobile: {df['Price(Mobile)'].sum()}")
# Out:
# 가구/인테리어: PC: 7900671059, Mobile: 7900671059
# 화장품/미용: PC: 9481455, Mobile: 9481455
# 스포츠/레저: PC: 49548785, Mobile: 49548785
# 식품: PC: 144700, Mobile: 144700
# 패션잡화: PC: 5653030, Mobile: 5653030
# 출산/육아: PC: 65058680, Mobile: 65058680
# 디지털/가전: PC: 7777378, Mobile: 7777378
# 생활/건강: PC: 414339829, Mobile: 414339829
# 패션의류: PC: 4459740, Mobile: 4459740
# 여가/생활편의: PC: 3050240, Mobile: 3050240

# %%
idx_distinct_df.loc[idx_distinct_df['Click'] == 0]['Cost'].sum()
# Out:
# 0.0

# %%
idx_distinct_df.sort_values(by=['Click'], ascending=False).loc[idx_distinct_df['Click'] > 0]
# Out:
#            index  Impression  Click      Cost  Sum of AD rank   Bid  \
# 122274   1652151       13460    361  126670.0        1.233804   500
# 289756   3510537       14965    275   86690.0        1.836619    50
# 229463   6350550        6716    147   98730.0        2.106909  1000
# 10371    3763358       11322    145   19000.0        1.017488   300
# 314429   3510568        5141    136   55350.0        1.041626    50
# ...          ...         ...    ...       ...             ...   ...
# 865814   8816404          63      1     390.0        5.269841   500
# 1056882    53617          85      1     200.0        1.000000   500
# 1112996  1322672          20      1     120.0        2.000000   500
# 7523      517450          23      1      50.0        8.695652    50
# 5252     8131223          11      1      50.0        6.090909    50
#
#          Price(PC)  Price(Mobile)  Delivery Fee Category Name 1  \
# 122274      399000         399000             0           생활/건강
# 289756      117900         117900             0           생활/건강
# 229463      189000         189000             0         가구/인테리어
# 10371       334010         334010             0          스포츠/레저
# 314429      539000         539000             0           생활/건강
# ...            ...            ...           ...             ...
# 865814      289000         289000            -1         가구/인테리어
# 1056882      31500          31500          2900           생활/건강
# 1112996      25000          25000          3000           생활/건강
# 7523        129000         129000            -1         가구/인테리어
# 5252         89900          89900            -1         가구/인테리어
#
#         Category Name 2 Category Name 3 Category Name 4      date
# 122274          문구/사무용품        다이어리/플래너          캘린더/달력  20221108
# 289756          문구/사무용품        다이어리/플래너          캘린더/달력  20221116
# 229463         서재/사무용가구              의자           목받침의자  20221114
# 10371                캠핑            캠핑가구           캠핑테이블  20221031
# 314429          문구/사무용품        다이어리/플래너          캘린더/달력  20221117
# ...                 ...             ...             ...       ...
# 865814             주방가구           식탁/의자            식탁세트  20221212
# 1056882           원예/식물              조화             NaN  20221219
# 1112996            주방용품            주방잡화              쟁반  20221226
# 7523           서재/사무용가구              책상           독서실책상  20221031
# 5252               침실가구             화장대           일반화장대  20221031
#
# [9617 rows x 14 columns]

# %% [markdown]
# ### Log

# %%
log
# Out:
#          Unnamed: 0               uid action_type category1  category2  \
# 0                 0  avpKyWMn/xEADNlb        View      주방용품     그릇·홈세트
# 1                 1  0+5vEmGkOuAAB5j2      Basket       패브릭         매트
# 2                 2  r8DXy2OtSl8AAojG        View       패브릭     커튼·부자재
# 3                 3  dC9Fl2Ly9lcADrTn   Highlight     데코·식물     플라워·식물
# 4                 4  09gKcGLg0I8ACyQy        View        가구     진열장·책장
# ...             ...               ...         ...       ...        ...
# 5659536     5659536  PUpxWWMWdcIACR2B        View      주방용품     칼·커팅기구
# 5659537     5659537  PVMstmNg4I4ADq9R      Basket        가구     진열장·책장
# 5659538     5659538  diRXdmN49dUABrVo        View        가구  테이블·식탁·책상
# 5659539     5659539  dusFzWJvp5cADhZW        View    가전·디지털       계절가전
# 5659540     5659540  bgy5ZGOszc4ADrmd        View        가구     화장대·콘솔
#
#          category3         collect_time geoip_city_name useragent_os  \
# 0          식판·나눔접시  2022-12-29 17:29:02     Seongnam-si      Windows
# 1         주방·다용도매트  2022-12-29 12:56:38       Yongin-si      Windows
# 2             암막커튼  2022-12-29 17:11:30           Seoul          iOS
# 3            화병·화분  2022-12-29 17:54:30  Gwangmyeong-si      Windows
# 4               책장  2022-12-29 18:45:05       Jongno-gu     Mac OS X
# ...            ...                  ...             ...          ...
# 5659536  채칼·다지기·강판  2022-12-28 20:01:30           Seoul      Android
# 5659537         책장  2022-12-28 14:30:09           Jinju      Windows
# 5659538         식탁  2022-12-29 12:45:13           Gunpo      Android
# 5659539   전기히터·온풍기  2022-12-28 11:07:30           Seoul      Android
# 5659540      일반화장대  2022-12-29 08:14:39           Iksan          iOS
#
#          viewrate  viewtime
# 0           100.0     80033
# 1             0.0         0
# 2           100.0       947
# 3             0.0         0
# 4           100.0      1238
# ...           ...       ...
# 5659536     100.0     13893
# 5659537       0.0         0
# 5659538     100.0     47217
# 5659539     100.0     54030
# 5659540       0.0         0
#
# [5659541 rows x 11 columns]

# %%
uid_distinct_df = log.drop_duplicates(['uid'])

# %%
# 유저 수
uids = list(set(log['uid'].to_list()))
print(len(uids))
# Out:
# 828537

# %%
devices = list(set(log['useragent_os'].to_list()))
devices
# Out:
# ['Android',
#  'Fedora',
#  'Mac OS X',
#  'Linux',
#  'Ubuntu',
#  'OpenBSD',
#  'iOS',
#  'Other',
#  'Windows',
#  'CentOS',
#  'FreeBSD',
#  'Tizen',
#  'Chrome OS']

# %%
for device in devices: 
    df = uid_distinct_df.loc[uid_distinct_df['useragent_os'] == device]
    print(f"{device}: {df['useragent_os'].count()}")
# Out:
# Android: 326563
# Fedora: 2
# Mac OS X: 29204
# Linux: 1892
# Ubuntu: 36
# OpenBSD: 1
# iOS: 173581
# Other: 958
# Windows: 296104
# CentOS: 47
# FreeBSD: 1
# Tizen: 21
# Chrome OS: 127

# %%
action_types = list(set(log['action_type'].to_list()))
action_types
# Out:
# ['Basket', 'Copy', 'Highlight', 'View', 'SINF']

# %%
for _type in action_types:  
    df = uid_distinct_df.loc[uid_distinct_df['action_type'] == _type]
    print(f"{_type}: {df['action_type'].count()}")
# Out:
# Basket: 6740
# Copy: 3203
# Highlight: 19148
# View: 794961
# SINF: 4485

# %%
categorys = list(set(log['category1'].to_list()))
print(len(categorys))
print(categorys)
# Out:
# 3373
# ['언커먼하우스', '아이하우스', 'JD 홈드레싱', '페이퍼가든', '스테이라움', 'kitchen utensils', '퀵슬립', '디자인벤트', '까르다', '자리스튜디오', '파이렉스 밀크글라스', '알론맨션', '쌍수동', '세계로가구', '목화나무숲', '세레스홈', '테리파머', 'GAWON', 'Herman Miller', '어반휴', '맛있는유혹', '비컨드', '타공판닷컴', '하모벨', '까르데코', '자코모', '露营用品', '슈나츠', '백조씽크', '스누피', '원탑코리아', '하니팜', '헤르짐머', '아꾸드레', '셈프레샵', '다은담다', '케이엘', '가또페로', '블루밍홈', '미묘한피크닉', '바스클립', '렛씨온니굿띵', '루보', '커먼키친', '다올퍼니', '부자오빠', '돌체비비드가구', '지아지조마켓', '세비앙', '하우심플', '월플랜', '파인블루', '베베앙 아기물티슈', '라이브워크', '본드팩토리', '모즈', '데스커', '칼리아', '메종수피아', '오프라이스', '위띵크', '앤커', '씨에스리빙', '라로퍼니처', '핸슨', '레이앤드', '에이비퍼니쳐', '신비생활', '티렌토가구', '팜데코', '플라워트리', '서운아트', '하니니키친', '가담다', '로제프', '슬라이락', '더올로르', 'X쇼핑', '제이엔터프라이스', '더 아트', '이한리빙', '까사밀라', '블랑드제이', '몽스홈', 'Rinnai', '르난세', '송군가구팩토리', '쥬앤크홈', '퍼시스(FURSYS)', '오덴세', 'LX하우시스', '공식 카카오프렌즈', '메종드샹스', '샤오미', '제이디퍼니처', '심플팩토리', '브라더', '뷰하우스', '식탁연구소', '톰의다락방', '펠리스침대', '까사지오', '요와 ioua', '모두의러그', '아이닉', '엠리빙', '照明', '홈랩', '5월의일상', '제이앤제이', '두닷', '메이트', '정이유니 마켓', '까사에라', 'Know-How ', '애들라인', '잼스튜디오', '엑토', '신광섭도자기', '이지온행거', '히트디자인', '도르미베네', 'marci', '몬즈', '세이지폴', '필리플레이스', '우디크', '101do', '럼버잭', '핀카', '상일리베가구', '리센', '아토앤알로', '바이칸', '앤더라인', '가구밸리', '언제나 무드', '버디캣', '도든', 'ทารก   เด็ก', '다올라이팅', '어긋난몰', '로마네', '까사인루체', 'Électroménager Numérique', '마이엘가구', '솜시', '테이블앤테이블', '생활탐구', '클린업', '묶음배송 상품', '코코플라워', '홈앤하우스', 'GALON (갈롱)', '플라비', '웨스트프롬', '더리체', '허먼밀러', '마이 시리즈', '초코펫하우스', '엔투엔퍼니쳐', 'ZARA HOME', '룰루홈 별빛감성', '매직픽스', '르헤브', '살랑공간', '아이리스', '콜렉토그라프', '이에스알', '더코이즈', '스페이스', 'sogonsogon', '핸드메이드썸', '네이쳐리빙', '지이라이프', '라레스가구', '드웰링컴퍼니', '가온퍼니처', '專有技術', 'wallace & sewell', '남다른홈앤키친', '오키멧', '리에즈', '미스터허브', 'Amie Moa', '코세드', '이지철물', '커텐클럽', '샵베딩', '모두쿡', 'WMF', '퍼플뉴퍼니처', '퍼니하우스', '엠디자인', 'KGS금강', '제노가구', '대우', '삼성전자', '레나에너지', 'NNN', '모넥스', '메이해리', '세스코', '더브리즈에리아', '프리바토우', '그랑수', '우드앤쏘잉', '맘스보드', '노아가구', '홈앤힐', '아이앤', '스칸디앤홈', '소파와우엠', '린튼', '악당스토어', '퍼니매스', '아르케퍼니처', '러브아우어띵', '드레텍', '대한', '모머위켄드', '미쓰나이롱', '아사셀렉션', '리프홈', '제로퍼제로', '하이파가구', '애구애구', '게디', '지호맘메종', '라자가구', '피카소가구', 'TWB', '칼딘', '애슐리 홈스토랑', '더바람', '디에프퍼니처', '앙비까사', '쿡에버', '리치웰', '크리타', '돌체구스토', '다이슨', '큐빅스', '家庭用品', 'MJK', '베카', '일일일상', '하늘창가구', '밍이네가든', '헤링하우스', '데코아트', 'VOLTA(볼타)', '페니체(FENICE)', 'MMMM', '하우스버디', '플랜타하임', '브리스크스타일', '아피나 모블러', '달스네가게', '아르테미데', 'BAS', '메이드파니', '디클루', '마티노가구', '꼬끄시그루', '룸스토어', '오데르(odere)', '마틸라', '트렌즈', '글라스락', '저스틴퍼니처', '준우드', '디노데코', '유어그라피', '나눔조명', '아이데뉴', '메이크가구', '디자인에버', '생활용품', '퍼닉에스엠', '크림펫', '업테리어', '이프자인', '제이라이팅', '리모델링·홈케어', '매즘', '와이타운', '일루이홈', 'kokiri furniture', '양성국갤러리', '까사펠리체', '키친팩토리', '라세라미끄', '소르르홈데코', '돌라도르', 'Household goods', '조명뱅크', '코아스', '비투스매트리스', 'SELBY', '에피하임', '올데이앤드', '하우지안', '브라이튼', '아망떼', '우드블랑', '일루스터', '리뉴월', '미스모네', '키모스리빙', '어도어삼십삼', '레보떼', '아리프', '바자르', '자연일상', '플레이모빌', 'أثاث المنزل', '홈씨씨 인테리어', '킨키로봇', '일일공칠', '비햅핀', '슬로홈', '뉴욕레트로', '라헨느', '레이브', '엘데팩토리', '이크홈', '인하우스', '0001', 'DDWD', '다행의살림', '이누스', '인아트', 'mutfak eşyaları', '에이트하우스', '깃든', '노리터보드', '사브르', '카우프만', 'mooi studio', '우드보이', '데일리스너그', '맨드롱', '마이센스', '홈즈리빙', '마로', '가누', '파나소닉', 'VIVA', 'one place', '209애비뉴', 'vitra', 'FRITZ HANSEN', '아메리카나베드', '티엔느디자인', '인테홀릭', '212 캔들', '매직쉐프', '우아한가구', '잇데코', '우드하임', '밀레마', '덜튼', '스코홈', '베스트렉', '아리스', '프리즘코리아', '에이롤', '마고스완', '오가니크라프트', '크로니클', '꿀팝', '삼익가구', '에어메이드', 'Decor Plant', '웨글루홈', 'MURMUR', '네모라인', '공간디자인', '리바트', '로이첸', '홈메이드', '봄날프로젝트', 'ファブリック', '위글위글', '까르엠가구', '예딤', '플레이어바웃', '구앤즈', '비츠조명', '베드앤데코', '시럽실험실', '이즈네이처', '살림씨', '한경희생활과학', '레뉘앙스', '피토니아가구', '바솔트홈', '베비언스', '코지테이블', '오늘의 무드', '&tradition', '프티트리아농', 'Kitchen utensils', '오에이데스크', '쓱싹', '림드(RYMD)', 'Helen B', '코즈', '자주', '풀라이프', '따스한정원', 'mellbrown', '로즈니', '허레이', '위즐리', 'marui', 'A6마트', '제이블룸', '로지텍', '네파', '비에스디자인', '솔로리빙', '디허브', '아쿠아릭', '빠하지에스띠발르', '리아즈하우스', '아볼트', '리피트리', 'at home', '쿠션마켓', '카레클린트', '카모메키친', '블로홈', '러그마켓', '왈로우', '리튼', '더블에프컬러랩', 'đồ nội thất', '슈렉앳홈', '한아름리빙', '아이엔지홈', '厨具', '닷홈', 'agt', '디쟈트가구', '테이블포투', '파뜨', '롬버스', '아이니드가구', '누누레빗', '바디프랜드', '차렌시아', '일렉트로룩스', '스윗브릿지', '달리빙앤', '가구느낌', '홈디자인연 ...

# %%
ips = list(set(log['geoip_city_name'].to_list()))
print(len(ips))
print(ips)
# Out:
# 3198
# [nan, 'Kluang', 'Greifswald', 'Toluca', 'Hampyeong-gun', 'Puyallup', 'Quincy', 'Nichinan', 'Fort Collins', 'Gwangyang', 'Karur', 'Jakarta', 'Vinh Yen', 'Chesham', 'Yangyang', 'Hikone', 'Novokuznetsk', 'Tauranga', 'Subang', 'Taizhou', 'Yachiyo', 'Sergiyev Posad', 'Mittenwald', 'Kebumen', 'Luanda', 'Santa Rosa', 'Rancho Cucamonga', 'Suresnes', 'Frederick', 'Sannicandro Garganico', 'Junction City', 'Pflugerville', 'Salvador', 'Maputo', 'Scottsdale', 'Natal', 'Delmar', 'Council Bluffs', 'Okemos', 'Uyo', 'Cao Bang', 'Luoyang', 'Tashtagol', 'La Plata', 'Eagle River', 'Huanggang', 'Rafael Calzada', 'Belen de Umbria', 'Karlsruhe', 'Lenexa', 'Whangarei', 'Richardson', 'Kew', 'San Marcos', 'Manosque', 'Cunha', 'Minamitsukaguchicho', 'Bavel', 'New Haven', 'Choeng Thale', 'Mungyeong', 'Cachoeirinha', 'Phan Thong', 'Verkhneye Dubrovo', 'Malacca', 'Binan', 'Wheeling', 'Shirokanedai', 'Perugia', 'Jinan', 'Sangju-si', 'Lynnwood', 'Querétaro City', 'Upper Sandusky', 'Yahiro', 'Centreville', 'Glenfield', 'Haerkingen', 'Oxford', 'Una', 'Daedeok', 'Tyreso Strand', 'Sacheon-si', 'Pakpattan', 'Dombivali', 'Busan', 'Seongju-gun', 'Kalamazoo', 'Lyndhurst', 'Hung Yen', 'Gimhae', 'Sao Goncalo', 'Xiangyang', 'Adelaide', 'Camden', 'Szczecin', 'Chengxiang', 'Lauingen', 'Nozawa', 'Sellersville', 'Nossa Senhora do Socorro', 'Mosta', 'Kazan’', 'Srednyaya Akhtuba', 'Walled Lake', 'Buk-gu', 'Latham', 'Levittown', 'Guatemala City', 'Novorossiysk', 'Douai', 'Itapirapua Paulista', 'Bergeijk', 'Crowley', 'Nassau', 'Cypress', 'Apex', 'Hoengseong-gun', 'Taoyuan City', 'Niigata', 'San Miguel de Allende', 'Iksan', 'El Cajon', 'Sopot', 'Vũng Tàu', 'Oguradai', 'Kenmore', 'Kollam', 'Ichikawa', 'Ankenes', 'Sandy', 'Addlestone', 'Lakewood', 'Zhubei', 'Sheung Wan', 'Bo', 'Mission Viejo', 'Spearfish', 'Solana Beach', 'Bell Ville', 'Chapel Hill', 'Koesan', 'Hoi An', 'Gastonia', 'Kyoto', 'Kassel', 'Loei', 'Avon Lake', 'Columbia', 'Hopewell', 'Bac Giang', 'Gifu City', 'Hanover', 'Avdiivka', 'Mataró', 'Hwasun-gun', 'Gay', 'Collierville', 'Fall River', 'Aurora', 'Untersiggenthal', 'Roslyn Heights', 'Rosario', 'Muncie', 'Gaborone', 'La Calera', 'Illingen', 'Gambir', 'Vang Vieng', 'Montpellier', 'Sai Kung', 'Ajmer', 'Yuseong', 'Azabudai', 'Thai Binh', 'Asan', 'Bremen', 'Colchester', 'Daedeok-gu', 'Santa Clara', 'Monterrey', 'Ludhiana', 'Cyberjaya', 'Londrina', 'Buan-gun', 'Charlottesville', 'Yongsan-gu', 'Taichung', 'Saint Venera', 'Palmahim', 'Miguelopolis', 'Offenbach', 'Washington', 'Laguna Beach', 'Donghae-si', 'Oslo', 'Seocheon-gun', 'Sawyers Valley', 'Morristown', 'Ypsilanti', 'Ban Pho', 'Tirana', 'Solihull', 'Trieste', 'Wando-gun', 'Davis', "Rossosh'", 'College Station', 'Saint-Pierre', 'Jung-gu', 'Wildomar', 'Dej', 'Boydton', 'Oryu-dong', 'Muan', 'Pathum Thani', 'Concord', 'Tuy Hoa', 'Waldthurn', 'Surakarta', 'Ellicott City', 'Ban Pong', 'Xenia', 'Phoenix', 'Cobourg', 'Friedrichshafen', 'Falls Church', 'Hongcheon-gun', 'Okinawa', 'Patton', 'Ocean Springs', 'Sejong', 'Joinville', 'Cheyenne', 'Ooltewah', 'Odessa', 'Happy Valley', 'District Heights', 'Napier City', 'Darien', 'Alvaro Obregon', 'Tamamura', 'Haeundae-gu', 'Olney', 'Gmina Mała Wieś', 'Nagareyama', 'Mito', 'Kodaira', 'Cedar Knolls', 'La Conversion', 'San Nicolás de los Arroyos', 'Whiteville', 'Moradabad', 'Surbiton', 'Danyang', 'Kuala Belait', 'Gimje-si', 'Glendale', 'Dongjak-gu', 'Aomori', 'Changsu', 'Laishan', 'Yuba City', 'Shoreham', 'Siena', "Yangch'on-gu", 'Mississauga', 'Lampang', 'Pinamar', 'To Kwa Wan', 'Kushima', 'Suva', 'Arlington', 'Tulun', 'Marseille', 'Vi Thanh', 'Calumpit', 'Bellefontaine', 'Riga', 'Brasília', 'Salhus', 'Bang Bon', 'Pohang-si', 'Thames Ditton', 'Henderson', "Vol'ginskiy", 'Ko Samui', 'Nishiochiai', 'Tan Phu Thuong', 'Myszkow', 'Songpa-gu', 'Ban Phue', 'Dharwad', 'Osan-hanongmaeul', 'Aubagne', 'Svobodnyy', 'Saitama', 'St. Gallen', 'Wyandanch', 'Adana', 'El Paso', 'Woodstock', 'Utsunomiya', 'Des Moines', 'Hai Duong', 'Warwick', 'Sorocaba', 'Perai', 'Miami Beach', 'Gramado', 'Cheongyang' ...
